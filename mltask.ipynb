# %% [markdown]
# # MAIN TASK
#
# Our main task is to predict **tip_amount** column in the dataset. We
# find this interesting as an accurate fare prediction could be valuable for both drivers and
# passengers to estimate trip costs.
#
# We are going to solve a regression task, then the algorithms we are expecting to implement
# are linear regression, decision tree regression, random forest regressor and gradient-boosted
# tree regressor. We are going to be measuring the performance of each of them and
# evaluating the results given with metrics like Root Mean Squared Error, Mean Absolute Error
# and R-Squared.

# %%
import pyspark
from pyspark.sql.functions import min, max

spark = (pyspark.sql.SparkSession.builder
         .appName("tip prediction")
         .config("spark.executor.memory", "6g")
         .config("spark.driver.memory", "6g")
         .getOrCreate())

data = spark.read.parquet("src/yellow_tripdata_2024-12.parquet")
data.show()
# Out:
# 25/05/14 16:32:25 WARN Utils: Your hostname, SurfaceMateo resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/05/14 16:32:25 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/14 16:32:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       2| 2024-12-01 00:12:27|  2024-12-01 00:31:12|              1|         9.76|         1|                 N|         138|          33|           1|       38.0|  6.0|    0.5|      4.72|         0.0|                  1.0|       51.97|                 0.0|       1.75|
# |       2| 2024-11-30 23:56:04|  2024-12-01 00:28:15|              1|         7.62|         1|                 N|         158|          42|           1|       37.3|  1.0|    0.5|      8.46|         0.0|                  1.0|       50.76|                 2.5|        0.0|
# |       2| 2024-12-01 00:50:35|  2024-12-01 01:24:46|              4|        20.07|         2|                 N|         132|         236|           2|       70.0|  0.0|    0.5|       0.0|        6.94|                  1.0|       82.69|                 2.5|       1.75|
# |       2| 2024-12-01 00:18:16|  2024-12-01 00:33:16|              3|         2.34|         1|                 N|         142|         186|           1|       15.6|  1.0|    0.5|      4.12|         0.0|                  1.0|       24.72|                 2.5|        0.0|
# |       2| 2024-12-01 00:56:13|  2024-12-01 01:18:25|              1|         5.05|         1|                 N|         107|          80|           1|       26.8|  1.0|    0.5|       5.0|         0.0|                  1.0|        36.8|                 2.5|        0.0|
# |       1| 2024-12-01 00:21:17|  2024-12-01 00:37:22|              1|          4.3|         1|                 N|         249|         141|           1|       20.5|  3.5|    0.5|       5.1|         0.0|                  1.0|        30.6|                 2.5|        0.0|
# |       2| 2024-12-01 00:04:53|  2024-12-01 00:31:03|              1|         7.66|         1|                 N|         186|          52|           1|       35.2|  1.0|    0.5|      8.04|         0.0|                  1.0|       48.24|                 2.5|        0.0|
# |       1| 2024-12-01 00:15:28|  2024-12-01 00:20:13|              1|          0.3|         1|                 N|         148|         148|           3|        5.8|  3.5|    0.5|       0.0|         0.0|                  1.0|        10.8|                 2.5|        0.0|
# |       1| 2024-12-01 00:38:54|  2024-12-01 01:03:46|              1|          9.4|         1|                 N|         234|         244|           1|       39.4|  3.5|    0.5|       0.0|         0.0|                  1.0|        44.4|                 2.5|        0.0|
# |       2| 2024-12-01 00:00:21|  2024-12-01 00:05:27|              2|         0.72|         1|                 N|         211|         231|           1|        7.2|  1.0|    0.5|      2.44|         0.0|                  1.0|       14.64|                 2.5|        0.0|
# |       2| 2024-12-01 00:07:13|  2024-12-01 00:20:57|              2|         3.54|         1|                 N|         231|          48|           1|       17.7|  1.0|    0.5|      4.54|         0.0|                  1.0|       27.24|                 2.5|        0.0|
# |       2| 2024-12-01 00:34:04|  2024-12-01 00:44:33|              1|         1.38|         1|                 N|          68|         137|           1|       10.7|  1.0|    0.5|       3.0|         0.0|                  1.0|        18.7|                 2.5|        0.0|
# |       2| 2024-12-01 00:57:27|  2024-12-01 01:00:44|              2|         0.45|         1|                 N|         230|         162|           2|        5.1|  1.0|    0.5|       0.0|         0.0|                  1.0|        10.1|                 2.5|        0.0|
# |       1| 2024-12-01 00:02:07|  2024-12-01 00:19:36|              3|          2.7|         1|                 N|         100|         239|           1|       17.7|  3.5|    0.5|       4.5|         0.0|                  1.0|        27.2|                 2.5|        0.0|
# |       2| 2024-12-01 00:07:12|  2024-12-01 00:07:25|              1|         0.03|         1|                 N|         262|         262|           4|       -3.0| -1.0|   -0.5|       0.0|         0.0|                 -1.0|        -8.0|                -2.5|        0.0|
# |       2| 2024-12-01 00:07:12|  2024-12-01 00:07:25|              1|         0.03|         1|                 N|         262|         140|           4|        3.0|  1.0|    0.5|       0.0|         0.0|                  1.0|         8.0|                 2.5|        0.0|
# |       2| 2024-12-01 00:30:37|  2024-12-01 00:33:50|              1|         0.48|         1|                 N|         237|         236|           1|        5.1|  1.0|    0.5|      2.02|         0.0|                  1.0|       12.12|                 2.5|        0.0|
# |       2| 2024-12-01 00:43:15|  2024-12-01 00:59:01|              1|         1.77|         1|                 N|         113|         249|           1|       14.9|  1.0|    0.5|       1.0|         0.0|                  1.0|        20.9|                 2.5|        0.0|
# |       1| 2024-12-01 00:03:22|  2024-12-01 00:16:23|              1|          2.1|         1|                 N|         142|         141|           1|       14.2|  3.5|    0.5|      1.92|         0.0|                  1.0|       21.12|                 2.5|        0.0|
# |       1| 2024-12-01 00:24:46|  2024-12-01 00:27:10|              1|          0.6|         1|                 N|         263|         263|           1|        5.1|  3.5|    0.5|      2.02|         0.0|                  1.0|       12.12|                 2.5|        0.0|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
value_counts = data.groupBy("passenger_count").count()
value_counts.show()
# Out:
# +---------------+-------+
# |passenger_count|  count|
# +---------------+-------+
# |              0|  30397|
# |              7|      7|
# |              6|  14205|
# |              9|      2|
# |              5|  22283|
# |              1|2531706|
# |              3| 133727|
# |              8|      9|
# |              2| 507628|
# |              4| 102116|
# |           NULL| 326291|
# +---------------+-------+

# %% [markdown]
# Looking at this we observe a couple of things:
# 1. We have many null values which we are eliminating as are possibly wrong values inserted in the dataset
# 2. Also having over 30k 0 values shows that there might be a data entry error
# 3. Having very few samples of 6,7,8, and 9
#
# Conclusions:
#
# Add values of columns 6,7,8 and 9 will be sum as the standard sports of a car are 5 and we thing that by doing this we could catch up relation with customers asking for bigger cars.

# %% [markdown]
# # DATA CLEANING + FEATURE ENGINEERING

# %% [markdown]
# We have find out that the data might need some preprocessing as some columns might not follow a proper structure for the models we are attempting to implement.
#
# It is necessary to understand the dataset first. As we need to find out which columns might be relevant for building our predictions. Checking the dictionary of the dataset: https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf we have found this columns relevant to predict the tip_amount:
#
# - passenger_count: Number of passengers in the vehicle.
# - trip_distance: distance in miles.
# - PULocationID: Pickup point of the trip. It has numerical values, each one represents a different town.
# - DOLocationID: Drooff point of the trip. Follows the same range as PULocationID
# - fare_amount

# %% [markdown]
# ### EXPLANATION:
# - We have decided to substract from pickup_datetime and dropoff_datetime a column of trip_duration. By substracting dopoff and pickup times and dividing it to obtain the minutes which might be useful as the models could perform better with it.
# - We have also decided to create a column pickup_hour taken from the  column which we find it is one of the most relevant features as taxis have different fees depending on the hour.
# - A new column day_of_week is added stracting its values from pickup_datetime
# - In the sample print at the beginning of the notebook we have realized that there is one row which has negative values in columns that must be >=0 so we have decided to apply a filter for those cases.
# - For passenger count column we are adapting the range of values of columns 6,7,8 and 9. Now the value 6 will represent 6 or more passengers. This is tue the lack of samples of values 7,8 or 9 which could cause a little of confusion for our models.

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import unix_timestamp, hour, col, dayofweek, when

data = data.dropna(subset=["PULocationID", "DOLocationID","passenger_count", "trip_distance", "fare_amount", "tip_amount", "tpep_pickup_datetime", "tpep_dropoff_datetime"])


dataClean = data.filter((col("trip_distance") > 0) & (col("fare_amount") > 0) & (col("tip_amount") >= 0))
dataFeat = dataClean.withColumn("trip_duration", (unix_timestamp("tpep_dropoff_datetime") - unix_timestamp("tpep_pickup_datetime"))/60)

dataFeat = dataFeat.withColumn("passenger_count_grouped", when(col("passenger_count") >= 6, 6).otherwise(col("passenger_count")))

#As the range of values goes from 1-7 and we want it to start at 0, we substract 1.
dataFeat = dataFeat.withColumn("day_of_week", dayofweek("tpep_pickup_datetime")-1)
dataFeat = dataFeat.withColumn("pickup_hour",hour("tpep_pickup_datetime"))
dataFeat = dataFeat.dropna(subset=["trip_duration", "pickup_hour", "day_of_week"])

columns = ["passenger_count_grouped","trip_distance","PULocationID","DOLocationID","fare_amount","trip_duration", "pickup_hour", "tip_amount", "day_of_week"]
selectedData = dataFeat.select(columns)
selectedData.show()
# Out:
# +-----------------------+-------------+------------+------------+-----------+-------------------+-----------+----------+-----------+
# |passenger_count_grouped|trip_distance|PULocationID|DOLocationID|fare_amount|      trip_duration|pickup_hour|tip_amount|day_of_week|
# +-----------------------+-------------+------------+------------+-----------+-------------------+-----------+----------+-----------+
# |                      1|         9.76|         138|          33|       38.0|              18.75|          0|      4.72|          0|
# |                      1|         7.62|         158|          42|       37.3|  32.18333333333333|         23|      8.46|          6|
# |                      4|        20.07|         132|         236|       70.0|  34.18333333333333|          0|       0.0|          0|
# |                      3|         2.34|         142|         186|       15.6|               15.0|          0|      4.12|          0|
# |                      1|         5.05|         107|          80|       26.8|               22.2|          0|       5.0|          0|
# |                      1|          4.3|         249|         141|       20.5| 16.083333333333332|          0|       5.1|          0|
# |                      1|         7.66|         186|          52|       35.2| 26.166666666666668|          0|      8.04|          0|
# |                      1|          0.3|         148|         148|        5.8|               4.75|          0|       0.0|          0|
# |                      1|          9.4|         234|         244|       39.4| 24.866666666666667|          0|       0.0|          0|
# |                      2|         0.72|         211|         231|        7.2|                5.1|          0|      2.44|          0|
# |                      2|         3.54|         231|          48|       17.7| 13.733333333333333|          0|      4.54|          0|
# |                      1|         1.38|          68|         137|       10.7| 10.483333333333333|          0|       3.0|          0|
# |                      2|         0.45|         230|         162|        5.1|  3.283333333333333|          0|       0.0|          0|
# |                      3|          2.7|         100|         239|       17.7| 17.483333333333334|          0|       4.5|          0|
# |                      1|         0.03|         262|         140|        3.0|0.21666666666666667|          0|       0.0|          0|
# |                      1|         0.48|         237|         236|        5.1|  3.216666666666667|          0|      2.02|          0|
# |                      1|         1.77|         113|         249|       14.9| 15.766666666666667|          0|       1.0|          0|
# |                      1|          2.1|         142|         141|       14.2| 13.016666666666667|          0|      1.92|          0|
# |                      1|          0.6|         263|         263|        5.1|                2.4|          0|      2.02|          0|
# |                      1|          1.8|         140|         163|       12.1| 10.483333333333333|          0|       0.0|          0|
# +-----------------------+-------------+------------+------------+-----------+-------------------+-----------+----------+-----------+
# only showing top 20 rows

# %%
value_counts = selectedData.groupBy("passenger_count_grouped").count()
value_counts.show()
# Out:
# [Stage 8:=============================================>           (12 + 3) / 15]
# +-----------------------+-------+
# |passenger_count_grouped|  count|
# +-----------------------+-------+
# |                      0|  29150|
# |                      6|  14091|
# |                      5|  22057|
# |                      1|2450879|
# |                      3| 128633|
# |                      2| 489550|
# |                      4|  95171|
# +-----------------------+-------+

# %% [markdown]
# ## CATEGORICAL COLUMNS(INDEXERS AND ENCODERS)

# %% [markdown]
# To handle categorical columns we are using StringIndexer. As each value in the column represents a town in NYC and this can cause problems as for example zone 100 is not twice good as zone 50, are just different places.
#
# For this StringIndexer is designed to convert a column of labels into a column of label indices.
#
# The same methodology is applied for columns day_of_week pickup_hour and passenger_count_grouped

# %%
indexer_pickup = StringIndexer(inputCol="PULocationID", outputCol="PULocationID_index", handleInvalid="keep")
indexer_dropoff = StringIndexer(inputCol="DOLocationID", outputCol="DOLocationID_index", handleInvalid="keep")

encoder_pickup = OneHotEncoder(inputCols=["PULocationID_index"], outputCols=["PULocationID_vec"], dropLast=False, handleInvalid="keep")
encoder_drop = OneHotEncoder(inputCols=["DOLocationID_index"], outputCols=["DOLocationID_vec"], dropLast=False, handleInvalid="keep")

indexer_day = StringIndexer(inputCol="day_of_week", outputCol="day_of_week_index", handleInvalid="keep")
indexer_hour = StringIndexer(inputCol="pickup_hour", outputCol="pickup_hour_index", handleInvalid="keep")
indexer_pass = StringIndexer(inputCol="passenger_count_grouped", outputCol="passenger_count_index", handleInvalid="keep")

encoder_day = OneHotEncoder(inputCols=["day_of_week_index"], outputCols=["day_of_week_vec"], dropLast=True)
encoder_hour = OneHotEncoder(inputCols=["pickup_hour_index"], outputCols=["pickup_hour_vec"], dropLast=True)
encoder_pass = OneHotEncoder(inputCols=["passenger_count_index"], outputCols=["passenger_count_vec"], dropLast=True)

# %% [markdown]
# ## MODEL TRAINING (LINEAR REGRESSION)

# %% [markdown]
# The steps we are following in order to train the different models are:
#
# 1. VectorAssembler: We have combined various ride details like trip_distance, fare_amount, and vectorized locations (PULocationID_vec, DOLocationID_vec), time (day_of_week_vec, pickup_hour_vec), and passenger count (passenger_count_vec) into one 'features' input for my model.
#
# 2. LinearRegression (lr): We have set up a Linear Regression model to learn how to predict the tip_amount based on that combined features vector.
#
# 3. ParamGridBuilder (paramGrid): We have defined a set of different tuning parameters (like regularization) for my Linear Regression, so I can test which combination works best.
#
# 4. RegressionEvaluator (evaluator): This will measure how good my model is by calculating the Mean Absolute Error (MAE) between its prediction and the actual tip_amount.
#
# 5. Pipeline: We have chained all my data prep steps (indexing, encoding, assembling) and the Linear Regression model into a single, streamlined workflow.
#
# 6. CrossValidator (cv): This tool will automatically train and test of our pipeline with all the different parameter sets from paramGrid using 3-fold cross-validation, picking the best one based on the MAE.
#
# 7. Data Sampling & Splitting: We have sampled 20% of the data (as in first stage the model took a vast amount of time to train) and then split it into dataTrain (for training/cross-validation) and dataTest (for final, unseen evaluation) to speed things up and properly assess performance.
#
# 8. Final Evaluation: After cv.fit(dataTrain) finds the best model (cvModel), We use it to make predictions on the dataTest. Then, We calculate MAE, RMSE, MSE, and R2 to see how well this final model performs on completely new data.

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.regression import LinearRegression, RandomForestRegressor
from pyspark.ml.pipeline import Pipeline

assemblerCols = ["trip_distance","PULocationID_vec","DOLocationID_vec","fare_amount","trip_duration", "day_of_week_vec", "pickup_hour_vec", "passenger_count_vec"
]

assembler = VectorAssembler(inputCols=assemblerCols, outputCol='features')

# %%
lr = LinearRegression(labelCol="tip_amount", featuresCol="features")
paramGrid = (ParamGridBuilder().addGrid(lr.regParam,[0.01,0.1,0.5])
             .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])
             .addGrid(lr.maxIter, [50, 100])
             .build())

evaluator = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mae')
pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, lr
])

# %% [markdown]
# ### Explanation:

# %%
cv = CrossValidator(estimator=pipeline, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=3, parallelism=2)

sampledData = selectedData.sample(withReplacement=False, fraction=0.2, seed=42)
dataTrain, dataTest = sampledData.randomSplit([0.8,0.2], seed=42)
dataTrain.show()
# Out:
# +-----------------------+-------------+------------+------------+-----------+------------------+-----------+----------+-----------+
# |passenger_count_grouped|trip_distance|PULocationID|DOLocationID|fare_amount|     trip_duration|pickup_hour|tip_amount|day_of_week|
# +-----------------------+-------------+------------+------------+-----------+------------------+-----------+----------+-----------+
# |                      0|          0.1|          48|          48|        3.0|0.6666666666666666|          6|       0.0|          4|
# |                      0|          0.1|         186|         164|       10.0|              10.2|         18|       2.8|          6|
# |                      0|          0.1|         262|         262|        3.0|              0.65|         18|       0.0|          5|
# |                      0|          0.1|         265|         265|        3.0|0.5333333333333333|          0|       0.0|          5|
# |                      0|          0.2|         100|         164|        6.5|               5.0|         10|       2.1|          6|
# |                      0|          0.2|         138|         138|        3.7|1.1833333333333333|         14|       0.0|          0|
# |                      0|          0.2|         162|         229|        3.7|1.2666666666666666|          9|       0.0|          1|
# |                      0|          0.2|         239|         239|        5.1|2.8833333333333333|         11|       0.0|          4|
# |                      0|          0.2|         246|         246|        4.4|1.7833333333333334|         15|       0.0|          1|
# |                      0|          0.2|         249|         249|        4.4|               2.1|         13|       0.0|          4|
# |                      0|          0.2|         262|         262|        4.4|              1.75|         13|       0.0|          0|
# |                      0|          0.3|          43|         163|        4.4|1.8333333333333333|         11|       2.0|          0|
# |                      0|          0.3|          68|          48|        9.3|12.916666666666666|         18|       0.0|          5|
# |                      0|          0.3|          68|         100|        6.5|               5.4|         10|       0.0|          5|
# |                      0|          0.3|          68|         186|        6.5| 4.866666666666666|         14|       2.0|          0|
# |                      0|          0.3|         141|         141|        4.4|1.5333333333333334|         15|       0.0|          3|
# |                      0|          0.3|         141|         237|        5.8|               3.8|         18|      2.45|          5|
# |                      0|          0.3|         141|         237|        5.8|              4.45|         16|       0.0|          0|
# |                      0|          0.3|         143|         143|        4.4|1.5333333333333334|         19|       0.0|          1|
# |                      0|          0.3|         159|         159|        4.4|1.6666666666666667|          7|       0.0|          0|
# +-----------------------+-------------+------------+------------+-----------+------------------+-----------+----------+-----------+
# only showing top 20 rows

# %%
cvModel = cv.fit(dataTrain)
# Out:
# 25/05/14 16:48:25 WARN BlockManager: Block rdd_32_4 already exists on this machine; not re-adding it

# %% [markdown]
# ## MODEL EVALUATION

# %%
predictions = cvModel.transform(dataTest)
mae = evaluator.evaluate(predictions)
print("MAE on Test data:", mae)

rmse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='rmse')
rmse = rmse_eval.evaluate(predictions)
print("RMSE on Test Data:",rmse)

mse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mse')
mse = mse_eval.evaluate(predictions)
print(f"MSE on Test Data:",mse)

r2_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_evaluator.evaluate(predictions)
print("R2:", r2)
# Out:
# MAE on Test data: 1.9790390686393609
# RMSE on Test Data: 3.13747349613148
# MSE on Test Data: 9.843739938927492
# R2: 0.42887791081664683

# %% [markdown]
# ### RESULTS:
#
# - MAE is about 1.98, meaning on average, my tip predictions are off by roughly that amount.
# - The RMSE is higher, around $3.14, which suggests that while the average error is low, there are some larger prediction errors pulling this value up.
# - The MSE is 9.84 – this is the average of the squared errors and is what RMSE is derived from.
# - An R2 of approximately 0.43 indicates my model explains about 43% of the variability in taxi tips, which is a decent start."
#
# ### POSSIBLE IMPROVEMENTS:
#
# After some testing how adding more columns (like: pickup_hour, day_of_week,
#     is_night, is_weekend) could increase or decrease our model performance. The results obtained where worse, then we concluded leaving they are now:
#
# MAE on Test data: 2.0467288596114304
# RMSE on Test Data: 3.2195547766976675
# MSE on Test Data: 10.365532960156768

# %% [markdown]
# ## MODEL TRAINING(RANDOMFOREST)

# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline

rf = RandomForestRegressor(featuresCol="features", labelCol="tip_amount")

paramGridRF = (ParamGridBuilder()
               .addGrid(rf.numTrees, [10, 20])
               .addGrid(rf.maxDepth, [5, 10])
               .build())

pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, rf
])
evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")

cvRF = CrossValidator(estimator=pipeline,
                      estimatorParamMaps=paramGridRF,
                      evaluator=evaluator,
                      numFolds=3,
                      parallelism=2)

# %%
sampledData = selectedData.sample(withReplacement=False, fraction=0.2, seed=42)

# %%
cvModelRF = cvRF.fit(dataTrain)
predRF = cvModelRF.transform(dataTest)

evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")
print("Random Forest MAE:", evaluator.evaluate(predRF))

rmse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='rmse')
rmse = rmse_eval.evaluate(predRF)
print("RMSE on Test Data:",rmse)

mse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mse')
mse = mse_eval.evaluate(predRF)
print(f"MSE on Test Data:",mse)

r2_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_evaluator.evaluate(predRF)
print("R2:", r2)
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.util.SizeEstimator$ (file:/home/ls/miniconda3/envs/spark_env/lib/python3.12/site-packages/pyspark/jars/spark-core_2.12-3.5.4.jar) to field java.nio.charset.Charset.name
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.util.SizeEstimator$
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 25/05/14 16:52:30 WARN DAGScheduler: Broadcasting large task binary with size 1053.5 KiB
# 25/05/14 16:52:31 WARN DAGScheduler: Broadcasting large task binary with size 1568.0 KiB
# 25/05/14 16:52:32 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/14 16:52:45 WARN DAGScheduler: Broadcasting large task binary with size 1227.1 KiB
# 25/05/14 16:52:46 WARN DAGScheduler: Broadcasting large task binary with size 1909.1 KiB
# 25/05/14 16:52:48 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/05/14 16:52:50 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 25/05/14 16:53:05 WARN DAGScheduler: Broadcasting large task binary with size 1045.0 KiB
# 25/05/14 16:53:06 WARN DAGScheduler: Broadcasting large task binary with size 1539.6 KiB
# 25/05/14 16:53:08 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/14 16:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1216.6 KiB
# 25/05/14 16:53:23 WARN DAGScheduler: Broadcasting large task binary with size 1893.1 KiB
# 25/05/14 16:53:25 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/05/14 16:53:27 WARN DAGScheduler: Broadcasting large task binary with size 4.3 MiB
# 25/05/14 16:53:40 WARN DAGScheduler: Broadcasting large task binary with size 1039.4 KiB
# 25/05/14 16:53:41 WARN DAGScheduler: Broadcasting large task binary with size 1537.0 KiB
# 25/05/14 16:53:43 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/05/14 16:53:56 WARN DAGScheduler: Broadcasting large task binary with size 1286.6 KiB
# 25/05/14 16:53:57 WARN DAGScheduler: Broadcasting large task binary with size 2014.5 KiB
# 25/05/14 16:53:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/05/14 16:54:02 WARN DAGScheduler: Broadcasting large task binary with size 4.5 MiB
# 25/05/14 16:54:24 WARN DAGScheduler: Broadcasting large task binary with size 1249.5 KiB
# 25/05/14 16:54:27 WARN DAGScheduler: Broadcasting large task binary with size 2010.5 KiB
# 25/05/14 16:54:29 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/05/14 16:54:32 WARN DAGScheduler: Broadcasting large task binary with size 4.7 MiB
# Random Forest MAE: 2.019929460938898
# RMSE on Test Data: 3.172192155766229
# MSE on Test Data: 10.062803073104794
# [Stage 1685:===========================================>          (12 + 3) / 15]
# R2: 0.4161681281902655

# %% [markdown]
# ### RESULTS

# %% [markdown]
# - My MAE is about 2.02. This means, on average, my Random Forest predictions are off by this amount, which is just slightly higher than the 1.98 MAE I got with Linear Regression.
# - The RMSE is around 3.17. Similar to the Linear Regression (which was 3.14), this is higher than the MAE, still pointing to some larger prediction errors. It's also a touch higher than the previous model.
# - My MSE is 10.06. This is the average of squared errors, again slightly up from the Linear Regression's 9.84.
# - An R2 of approximately 0.416 shows my Random Forest model explains about 41.6% of the variability in tips. This is a little bit less than the 42.9% my Linear Regression model explained.
#
# Overall, it seems this particular Random Forest configuration performed slightly worse than my Linear Regression model on these metrics.

# %% [markdown]
# ## MODEL TRAINING(GBTREGRESSOR)

# %%
from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(labelCol="tip_amount", featuresCol="features", maxIter=30)

paramGrid = (ParamGridBuilder()
    .addGrid(gbt.maxDepth, [5, 7])
    .addGrid(gbt.maxIter, [50, 100])
    .addGrid(gbt.stepSize, [0.1, 0.2])
    .build())

evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")

pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, gbt
])

cv = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=paramGrid,
    evaluator=evaluator,
    numFolds=3,
    parallelism=2
)

# %%
cvModel = cv.fit(dataTrain)
# Out:
# 25/05/14 17:32:45 WARN BlockManager: Asked to remove block rdd_19124_12, which does not exist
# 25/05/14 17:33:06 WARN DAGScheduler: Broadcasting large task binary with size 1001.1 KiB
# 25/05/14 17:33:06 WARN DAGScheduler: Broadcasting large task binary with size 1003.4 KiB
# 25/05/14 17:33:07 WARN DAGScheduler: Broadcasting large task binary with size 1005.1 KiB
# 25/05/14 17:33:07 WARN DAGScheduler: Broadcasting large task binary with size 1005.6 KiB
# 25/05/14 17:33:07 WARN DAGScheduler: Broadcasting large task binary with size 1006.3 KiB
# 25/05/14 17:33:08 WARN DAGScheduler: Broadcasting large task binary with size 1007.4 KiB
# 25/05/14 17:33:08 WARN DAGScheduler: Broadcasting large task binary with size 1009.2 KiB
# 25/05/14 17:33:08 WARN DAGScheduler: Broadcasting large task binary with size 1000.0 KiB
# 25/05/14 17:33:08 WARN DAGScheduler: Broadcasting large task binary with size 1012.2 KiB
# 25/05/14 17:33:09 WARN DAGScheduler: Broadcasting large task binary with size 1001.6 KiB
# 25/05/14 17:33:09 WARN DAGScheduler: Broadcasting large task binary with size 1016.1 KiB
# 25/05/14 17:33:09 WARN DAGScheduler: Broadcasting large task binary with size 1002.1 KiB
# 25/05/14 17:33:09 WARN DAGScheduler: Broadcasting large task binary with size 1016.7 KiB
# 25/05/14 17:33:09 WARN DAGScheduler: Broadcasting large task binary with size 1002.8 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1017.2 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1004.0 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1018.0 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1006.1 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1018.8 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1009.5 KiB
# 25/05/14 17:33:10 WARN DAGScheduler: Broadcasting large task binary with size 1020.6 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1014.9 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1023.2 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1016.0 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1027.8 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1016.5 KiB
# 25/05/14 17:33:11 WARN DAGScheduler: Broadcasting large task binary with size 1029.8 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1017.3 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1030.3 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1018.3 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1031.1 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1020.8 KiB
# 25/05/14 17:33:12 WARN DAGScheduler: Broadcasting large task binary with size 1032.2 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1024.3 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1034.4 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1029.3 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1037.5 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1029.7 KiB
# 25/05/14 17:33:13 WARN DAGScheduler: Broadcasting large task binary with size 1042.4 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1044.5 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1030.3 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1031.0 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1045.0 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1032.1 KiB
# 25/05/14 17:33:14 WARN DAGScheduler: Broadcasting large task binary with size 1045.8 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1034.2 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1046.9 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1037.0 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1048.9 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1051.9 KiB
# 25/05/14 17:33:15 WARN DAGScheduler: Broadcasting large task binary with size 1040.8 KiB
# 25/05/14 17:33:16 WARN DAGScheduler: Broadcasting large task binary with size 1056.1 KiB
# 25/05/14 17:33:16 WARN DAGScheduler: Broadcasting large task binary with size 1041.7 KiB
# 25/05/14 17:33:16 WARN DAGScheduler: Broadcasting large task binary with size 1057.1 KiB
# 25/05/14 17:33:16 WARN DAGScheduler: Broadcasting large task binary with size 
KiB
# 25/05/14 17:34:41 WARN DAGScheduler: Broadcasting large task binary with size 1476.6 KiB
# 25/05/14 17:34:41 WARN DAGScheduler: Broadcasting large task binary with size 1467.2 KiB
# 25/05/14 17:34:41 WARN DAGScheduler: Broadcasting large task binary with size 1477.7 KiB
# 25/05/14 17:34:41 WARN DAGScheduler: Broadcasting large task binary with size 1468.8 KiB
# 25/05/14 17:34:42 WARN DAGScheduler: Broadcasting large task binary with size 1479.5 KiB
# ...
# 25/05/14 17:57:20 WARN DAGScheduler: Broadcasting large task binary with size 1239.4 KiB
# 25/05/14 17:57:20 WARN DAGScheduler: Broadcasting large task binary with size 1240.4 KiB
# 25/05/14 17:57:20 WARN DAGScheduler: Broadcasting large task binary with size 1242.2 KiB
# 25/05/14 17:57:20 WARN DAGScheduler: Broadcasting large task binary with size 1245.5 KiB
# 25/05/14 17:57:21 WARN DAGScheduler: Broadcasting large task binary with size 1248.3 KiB
# 25/05/14 17:57:21 WARN DAGScheduler: Broadcasting large task binary with size 1248.8 KiB
# 25/05/14 17:57:21 WARN DAGScheduler: Broadcasting large task binary with size 1249.4 KiB
# 25/05/14 17:57:22 WARN DAGScheduler: Broadcasting large task binary with size 1250.2 KiB
# 25/05/14 17:57:22 WARN DAGScheduler: Broadcasting large task binary with size 1252.0 KiB
# 25/05/14 17:57:22 WARN DAGScheduler: Broadcasting large task binary with size 1254.9 KiB
# 25/05/14 17:57:23 WARN DAGScheduler: Broadcasting large task binary with size 1258.2 KiB
# 25/05/14 17:57:23 WARN DAGScheduler: Broadcasting large task binary with size 1258.9 KiB
# 25/05/14 17:57:23 WARN DAGScheduler: Broadcasting large task binary with size 1259.4 KiB
# 25/05/14 17:57:24 WARN DAGScheduler: Broadcasting large task binary with size 1260.1 KiB
# 25/05/14 17:57:24 WARN DAGScheduler: Broadcasting large task binary with size 1261.2 KiB
# 25/05/14 17:57:24 WARN DAGScheduler: Broadcasting large task binary with size 1263.6 KiB
# 25/05/14 17:57:25 WARN DAGScheduler: Broadcasting large task binary with size 1266.0 KiB
# 25/05/14 17:57:25 WARN DAGScheduler: Broadcasting large task binary with size 1269.4 KiB
# 25/05/14 17:57:25 WARN DAGScheduler: Broadcasting large task binary with size 1270.8 KiB
# 25/05/14 17:57:26 WARN DAGScheduler: Broadcasting large task binary with size 1271.3 KiB
# 25/05/14 17:57:26 WARN DAGScheduler: Broadcasting large task binary with size 1271.9 KiB
# 25/05/14 17:57:26 WARN DAGScheduler: Broadcasting large task binary with size 1272.9 KiB
# 25/05/14 17:57:26 WARN DAGScheduler: Broadcasting large task binary with size 1274.7 KiB
# 25/05/14 17:57:27 WARN DAGScheduler: Broadcasting large task binary with size 1276.9 KiB
# 25/05/14 17:57:27 WARN DAGScheduler: Broadcasting large task binary with size 1280.7 KiB
# 25/05/14 17:57:27 WARN DAGScheduler: Broadcasting large task binary with size 1282.5 KiB
# 25/05/14 17:57:28 WARN DAGScheduler: Broadcasting large task binary with size 1283.0 KiB
# 25/05/14 17:57:28 WARN DAGScheduler: Broadcasting large task binary with size 1283.8 KiB
# 25/05/14 17:57:28 WARN DAGScheduler: Broadcasting large task binary with size 1284.9 KiB
# 25/05/14 17:57:29 WARN DAGScheduler: Broadcasting large task binary with size 1287.0 KiB
# 25/05/14 17:57:29 WARN DAGScheduler: Broadcasting large task binary with size 1290.2 KiB
# 25/05/14 17:57:29 WARN DAGScheduler: Broadcasting large task binary with size 1294.7 KiB
# 25/05/14 17:57:30 WARN DAGScheduler: Broadcasting large task binary with size 1296.1 KiB
# 25/05/14 17:57:30 WARN DAGScheduler: Broadcasting large task binary with size 1296.6 KiB
# 25/05/14 17:57:30 WARN DAGScheduler: Broadcasting large task binary with size 1297.3 KiB
# 25/05/14 17:57:31 WARN DAGScheduler: Broadcasting large task binary with size 1298.4 KiB
# 25/05/14 17:57:31 WARN DAGScheduler: Broadcasting large task binary with size 1300.4 KiB
# 25/05/14 17:57:31 WARN DAGScheduler: Broadcasting large task binary with size 1303.4 KiB
# 25/05/14 17:57:32 WARN DAGScheduler: Broadcasting large task binary with size 1307.5 KiB
# 25/05/14 17:57:32 WARN DAGScheduler: Broadcasting large task binary with size 1307.9 KiB
# 25/05/14 17:57:32 WARN DAGScheduler: Broadcasting large task binary with size 1308.4 KiB
# 25/05/14 17:57:33 WARN DAGScheduler: Broadcasting large task binary with size 1309.1 KiB
# 25/05/14 17:57:33 WARN DAGScheduler: Broadcasting large task binary with size 1310.2 KiB
# 25/05/14 17:57:33 WARN DAGScheduler: Broadcasting large task binary with size 1312.6 KiB
# 25/05/14 17:57:33 WARN DAGScheduler: Broadcasting large task binary with size 1316.5 KiB
# 25/05/14 17:57:34 WARN DAGScheduler: Broadcasting large task binary with size 1320.9 KiB
# 25/05/14 17:57:34 WARN DAGScheduler: Broadcasting large task binary with size 1321.5 KiB
# 25/05/14 17:57:35 WARN DAGScheduler: Broadcasting large task binary with size 1322.0 KiB
# 25/05/14 17:57:35 WARN DAGScheduler: Broadcasting large task binary with size 1322.8 KiB
# 25/05/14 17:57:35 WARN DAGScheduler: Broadcasting large task binary with size 1323.9 KiB
# 25/05/14 17:57:35 WARN DAGScheduler: Broadcasting large task binary with size 1325.9 KiB
# 25/05/14 17:57:36 WARN DAGScheduler: Broadcasting large task binary with size 1328.8 KiB
# 25/05/14 17:57:36 WARN DAGScheduler: Broadcasting large task binary with size 1333.1 KiB
# 25/05/14 17:57:36 WARN DAGScheduler: Broadcasting large task binary with size 1334.2 KiB
# 25/05/14 17:57:37 WARN DAGScheduler: Broadcasting large task binary with size 1334.8 KiB
# 25/05/14 17:57:37 WARN DAGScheduler: Broadcasting large task binary with size 1335.5 KiB
# 25/05/14 17:57:37 WARN DAGScheduler: Broadcasting large task binary with size 1336.6 KiB
# 25/05/14 17:57:38 WARN DAGScheduler: Broadcasting large task binary with size 1338.1 KiB
# 25/05/14 17:57:38 WARN DAGScheduler: Broadcasting large task binary with size 1340.5 KiB
# 25/05/14 17:57:38 WARN DAGScheduler: Broadcasting large task binary with size 1344.5 KiB
# 25/05/14 17:57:38 WARN DAGScheduler: Broadcasting large task binary with size 1346.5 KiB
# 25/05/14 17:57:39 WARN DAGScheduler: Broadcasting large task binary with size 1347.0 KiB
# 25/05/14 17:57:39 WARN DAGScheduler: Broadcasting large task binary with size 1347.8 KiB
# 25/05/14 17:57:40 WARN DAGScheduler: Broadcasting large task binary with size 1348.8 KiB
# 25/05/14 17:57:40 WARN DAGScheduler: Broadcasting large task binary with size 1350.8 KiB
# 25/05/14 17:57:40 WARN DAGScheduler: Broadcasting large task binary with size 1354.7 KiB
# 25/05/14 17:57:40 WARN DAGScheduler: Broadcasting large task binary with size 1359.7 KiB
# 25/05/14 17:57:41 WARN DAGScheduler: Broadcasting large task binary with size 1360.4 KiB
# 25/05/14 17:57:41 WARN DAGScheduler: Broadcasting large task binary with size 1360.9 KiB
# 25/05/14 17:57:41 WARN DAGScheduler: Broadcasting large task binary with size 1361.7 KiB
# 25/05/14 17:57:42 WARN DAGScheduler: Broadcasting large task binary with size 1362.5 KiB
# 25/05/14 17:57:42 WARN DAGScheduler: Broadcasting large task binary with size 1364.3 KiB
# 25/05/14 17:57:42 WARN DAGScheduler: Broadcasting large task binary with size 1367.0 KiB
# 25/05/14 17:57:43 WARN DAGScheduler: Broadcasting large task binary with size 1371.0 KiB
# 25/05/14 17:57:43 WARN DAGScheduler: Broadcasting large task binary with size 1372.1 KiB
# 25/05/14 17:57:43 WARN DAGScheduler: Broadcasting large task binary with size 1372.6 KiB
# 25/05/14 17:57:44 WARN DAGScheduler: Broadcasting large task binary with size 1373.4 KiB
# 25/05/14 17:57:44 WARN DAGScheduler: Broadcasting large task binary with size 1374.5 KiB
# 25/05/14 17:57:44 WARN DAGScheduler: Broadcasting large task binary with size 1376.5 KiB
# 25/05/14 17:57:45 WARN DAGScheduler: Broadcasting large task binary with size 1379.6 KiB
# 25/05/14 17:57:45 WARN DAGScheduler: Broadcasting large task binary with size 1384.2 KiB
# 25/05/14 17:57:45 WARN DAGScheduler: Broadcasting large task binary with size 1385.6 KiB
# 25/05/14 17:57:46 WARN DAGScheduler: Broadcasting large task binary with size 1386.1 KiB
# 25/05/14 17:57:46 WARN DAGScheduler: Broadcasting large task binary with size 1386.9 KiB
# 25/05/14 17:57:46 WARN DAGScheduler: Broadcasting large task binary with size 1388.0 KiB
# 25/05/14 17:57:46 WARN DAGScheduler: Broadcasting large task binary with size 1390.2 KiB
# 25/05/14 17:57:47 WARN DAGScheduler: Broadcasting large task binary with size 1393.5 KiB
# 25/05/14 17:57:47 WARN DAGScheduler: Broadcasting large task binary with size 1398.7 KiB
# 25/05/14 17:57:47 WARN DAGScheduler: Broadcasting large task binary with size 1401.0 KiB
# 25/05/14 17:57:48 WARN DAGScheduler: Broadcasting large task binary with size 1401.5 KiB
# 25/05/14 17:57:48 WARN DAGScheduler: Broadcasting large task binary with size 1402.3 KiB
# 25/05/14 17:57:48 WARN DAGScheduler: Broadcasting large task binary with size 1403.0 KiB
# 25/05/14 17:57:49 WARN DAGScheduler: Broadcasting large task binary with size 1404.8 KiB
# 25/05/14 17:57:49 WARN DAGScheduler: Broadcasting large task binary with size 1408.1 KiB
# 25/05/14 17:57:50 WARN DAGScheduler: Broadcasting large task binary with size 1413.6 KiB
# 25/05/14 17:57:50 WARN DAGScheduler: Broadcasting large task binary with size 1415.3 KiB
# 25/05/14 17:57:50 WARN DAGScheduler: Broadcasting large task binary with size 1415.8 KiB
# 25/05/14 17:57:50 WARN DAGScheduler: Broadcasting large task binary with size 1416.6 KiB
# 25/05/14 17:57:51 WARN DAGScheduler: Broadcasting large task binary with size 1417.7 KiB
# 25/05/14 17:57:51 WARN DAGScheduler: Broadcasting large task binary with size 1419.8 KiB
# 25/05/14 17:57:51 WARN DAGScheduler: Broadcasting large task binary with size 1422.9 KiB
# 25/05/14 17:57:52 WARN DAGScheduler: Broadcasting large task binary with size 1427.6 KiB
# 25/05/14 17:57:52 WARN DAGScheduler: Broadcasting large task binary with size 1428.9 KiB
# 25/05/14 17:57:52 WARN DAGScheduler: Broadcasting large task binary with size 1429.4 KiB
# 25/05/14 17:57:53 WARN DAGScheduler: Broadcasting large task binary with size 1430.0 KiB
# 25/05/14 17:57:53 WARN DAGScheduler: Broadcasting large task binary with size 1430.9 KiB
# 25/05/14 17:57:53 WARN DAGScheduler: Broadcasting large task binary with size 1432.7 KiB
# 25/05/14 17:57:54 WARN DAGScheduler: Broadcasting large task binary with size 1435.4 KiB
# 25/05/14 17:57:54 WARN DAGScheduler: Broadcasting large task binary with size 1438.7 KiB
# 25/05/14 17:57:54 WARN DAGScheduler: Broadcasting large task binary with size 1439.7 KiB
# 25/05/14 17:57:55 WARN DAGScheduler: Broadcasting large task binary with size 1440.2 KiB
# 25/05/14 17:57:55 WARN DAGScheduler: Broadcasting large task binary with size 1441.0 KiB
# 25/05/14 17:57:55 WARN DAGScheduler: Broadcasting large task binary with size 1441.8 KiB
# 25/05/14 17:57:56 WARN DAGScheduler: Broadcasting large task binary with size 1443.4 KiB
# 25/05/14 17:57:56 WARN DAGScheduler: Broadcasting large task binary with size 1445.8 KiB
# 25/05/14 17:57:56 WARN DAGScheduler: Broadcasting large task binary with size 1449.1 KiB
# 25/05/14 17:57:57 WARN DAGScheduler: Broadcasting large task binary with size 1449.8 KiB
# 25/05/14 17:57:57 WARN DAGScheduler: Broadcasting large task binary with size 1450.3 KiB
# 25/05/14 17:57:57 WARN DAGScheduler: Broadcasting large task binary with size 1451.1 KiB
# 25/05/14 17:57:58 WARN DAGScheduler: Broadcasting large task binary with size 1452.2 KiB
# 25/05/14 17:57:58 WARN DAGScheduler: Broadcasting large task binary with size 1454.3 KiB
# 25/05/14 17:57:58 WARN DAGScheduler: Broadcasting large task binary with size 1457.7 KiB
# 25/05/14 17:57:58 WARN DAGScheduler: Broadcasting large task binary with size 1463.0 KiB
# 25/05/14 17:57:59 WARN DAGScheduler: Broadcasting large task binary with size 1464.0 KiB
# 25/05/14 17:57:59 WARN DAGScheduler: Broadcasting large task binary with size 1464.6 KiB
# 25/05/14 17:58:00 WARN DAGScheduler: Broadcasting large task binary with size 1465.3 KiB
# 25/05/14 17:58:00 WARN DAGScheduler: Broadcasting large task binary with size 1466.4 KiB
# 25/05/14 17:58:00 WARN DAGScheduler: Broadcasting large task binary with size 1467.6 KiB
# 25/05/14 17:58:00 WARN DAGScheduler: Broadcasting large task binary with size 1469.7 KiB
# 25/05/14 17:58:01 WARN DAGScheduler: Broadcasting large task binary with size 1473.0 KiB
# 25/05/14 17:58:01 WARN DAGScheduler: Broadcasting large task binary with size 1474.3 KiB
# 25/05/14 17:58:02 WARN DAGScheduler: Broadcasting large task binary with size 1474.8 KiB
# 25/05/14 17:58:02 WARN DAGScheduler: Broadcasting large task binary with size 1475.6 KiB
# 25/05/14 17:58:02 WARN DAGScheduler: Broadcasting large task binary with size 1476.7 KiB
# 25/05/14 17:58:02 WARN DAGScheduler: Broadcasting large task binary with size 1479.0 KiB
# 25/05/14 17:58:03 WARN DAGScheduler: Broadcasting large task binary with size 1483.1 KiB
# 25/05/14 17:58:03 WARN DAGScheduler: Broadcasting large task binary with size 1489.2 KiB
# 25/05/14 17:58:03 WARN DAGScheduler: Broadcasting large task binary with size 1489.8 KiB
# 25/05/14 17:58:04 WARN DAGScheduler: Broadcasting large task binary with size 1490.3 KiB
# 25/05/14 17:58:04 WARN DAGScheduler: Broadcasting large task binary with size 1491.1 KiB
# 25/05/14 17:58:04 WARN DAGScheduler: Broadcasting large task binary with size 1492.1 KiB
# 25/05/14 17:58:05 WARN DAGScheduler: Broadcasting large task binary with size 1494.2 KiB
# 25/05/14 17:58:05 WARN DAGScheduler: Broadcasting large task binary with size 1497.7 KiB
# 25/05/14 17:58:05 WARN DAGScheduler: Broadcasting large task binary with size 1502.0 KiB
# 25/05/14 17:58:06 WARN DAGScheduler: Broadcasting large task binary with size 1502.4 KiB
# 25/05/14 17:58:06 WARN DAGScheduler: Broadcasting large task binary with size 1503.0 KiB
# 25/05/14 17:58:06 WARN DAGScheduler: Broadcasting large task binary with size 1503.7 KiB
# 25/05/14 17:58:07 WARN DAGScheduler: Broadcasting large task binary with size 1504.7 KiB
# 25/05/14 17:58:07 WARN DAGScheduler: Broadcasting large task binary with size 1506.9 KiB
# 25/05/14 17:58:07 WARN DAGScheduler: Broadcasting large task binary with size 1510.3 KiB
# 25/05/14 17:58:08 WARN DAGScheduler: Broadcasting large task binary with size 1514.6 KiB
# 25/05/14 17:58:08 WARN DAGScheduler: Broadcasting large task binary with size 1514.8 KiB
# 25/05/14 17:58:08 WARN DAGScheduler: Broadcasting large task binary with size 1515.3 KiB
# 25/05/14 17:58:09 WARN DAGScheduler: Broadcasting large task binary with size 1516.1 KiB
# 25/05/14 17:58:09 WARN DAGScheduler: Broadcasting large task binary with size 1517.1 KiB
# 25/05/14 17:58:09 WARN DAGScheduler: Broadcasting large task binary with size 1519.2 KiB
# 25/05/14 17:58:09 WARN DAGScheduler: Broadcasting large task binary with size 1522.6 KiB
# 25/05/14 17:58:10 WARN DAGScheduler: Broadcasting large task binary with size 1526.1 KiB
# 25/05/14 17:58:10 WARN DAGScheduler: Broadcasting large task binary with size 1527.0 KiB
# 25/05/14 17:58:11 WARN DAGScheduler: Broadcasting large task binary with size 1527.5 KiB
# 25/05/14 17:58:11 WARN DAGScheduler: Broadcasting large task binary with size 1528.3 KiB
# 25/05/14 17:58:11 WARN DAGScheduler: Broadcasting large task binary with size 1529.4 KiB
# 25/05/14 17:58:11 WARN DAGScheduler: Broadcasting large task binary with size 1531.8 KiB
# 25/05/14 17:58:12 WARN DAGScheduler: Broadcasting large task binary with size 1534.9 KiB
# 25/05/14 17:58:12 WARN DAGScheduler: Broadcasting large task binary with size 1539.3 KiB
# 25/05/14 17:58:12 WARN DAGScheduler: Broadcasting large task binary with size 1540.7 KiB
# 25/05/14 17:58:13 WARN DAGScheduler: Broadcasting large task binary with size 1541.2 KiB
# 25/05/14 17:58:13 WARN DAGScheduler: Broadcasting large task binary with size 1542.0 KiB
# 25/05/14 17:58:13 WARN DAGScheduler: Broadcasting large task binary with size 1543.1 KiB
# 25/05/14 17:58:14 WARN DAGScheduler: Broadcasting large task binary with size 1545.2 KiB
# 25/05/14 17:58:14 WARN DAGScheduler: Broadcasting large task binary with size 1548.6 KiB
# 25/05/14 17:58:14 WARN DAGScheduler: Broadcasting large task binary with size 1552.9 KiB
# 25/05/14 17:58:15 WARN DAGScheduler: Broadcasting large task binary with size 1554.8 KiB
# 25/05/14 17:58:15 WARN DAGScheduler: Broadcasting large task binary with size 1555.3 KiB
# 25/05/14 17:58:15 WARN DAGScheduler: Broadcasting large task binary with size 1556.1 KiB
# 25/05/14 17:58:16 WARN DAGScheduler: Broadcasting large task binary with size 1557.2 KiB
# 25/05/14 17:58:16 WARN DAGScheduler: Broadcasting large task binary with size 1559.3 KiB
# 25/05/14 17:58:16 WARN DAGScheduler: Broadcasting large task binary with size 1562.8 KiB
# 25/05/14 17:58:17 WARN DAGScheduler: Broadcasting large task binary with size 1567.4 KiB

# %% [markdown]
# ## MODEL EVALUATION

# %%
predictions = cvModel.transform(dataTest)

mae = evaluator.evaluate(predictions)
print("MAE on Test data:", mae)

rmse_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="rmse")
rmse = rmse_eval.evaluate(predictions)
print("RMSE on Test Data:", rmse)

mse_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mse")
mse = mse_eval.evaluate(predictions)
print("MSE on Test Data:", mse)

r2_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_eval.evaluate(predictions)
print("R2 on Test Data:", r2)
# Out:
# MAE on Test data: 1.9671959983206897
# RMSE on Test Data: 3.2530875945279334
# MSE on Test Data: 10.582578897671537
# [Stage 25253:==========================================>          (12 + 3) / 15]
# R2 on Test Data: 0.38601135274970066

# %% [markdown]
# ### RESULTS

# %% [markdown]
# - MAE: 1.97 – Slightly better than both Random Forest (2.02) and Linear Regression (1.98), indicating marginally lower average error.
#
# - RMSE: 3.25 – Higher than both Random Forest (3.17) and Linear Regression (3.14), showing it is more sensitive to larger errors.
#
# - MSE: 10.58 – Also higher, confirming that squared errors are larger on average.
#
# - R square: 0.39 – Lower than Random Forest (0.42) and Linear Regression (0.43), suggesting it explains less variance in the data.
#
# Overall, while Gradient Boost performs slightly better in terms of MAE, it is behind in RMSE, MSE, and R squared compared to the other models—especially Linear Regression, which appears to have the best overall performance here.

# %% [markdown]
# # FINAL CONCLUSIONS

# %% [markdown]
# ## References:
#
# https://stackoverflow.com/questions/73524197/pyspark-performing-one-hot-encoding
#
# https://www.datatechnotes.com/2021/05/mllib-linear-regression-example-with.html
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.ml.html
#
# https://github.com/RezvanRah/ML_TaxiFare_Prediction
#
# https://www.youtube.com/watch?v=HK4YW9qvQE8
