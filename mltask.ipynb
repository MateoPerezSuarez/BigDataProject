# %% [markdown]
# # MAIN TASK
#
# Our main task is to predict **tip_amount** column in the dataset. We
# find this interesting as an accurate fare prediction could be valuable for both drivers and
# passengers to estimate trip costs.
#
# We are going to solve a regression task, then the algorithms we are expecting to implement
# are linear regression, decision tree regression, random forest regressor and gradient-boosted
# tree regressor. We are going to be measuring the performance of each of them and
# evaluating the results given with metrics like Root Mean Squared Error, Mean Absolute Error
# and R-Squared.

# %%
import pyspark
from pyspark.sql.functions import min, max

spark = (pyspark.sql.SparkSession.builder
         .appName("tip prediction")
         .config("spark.executor.memory", "6g")
         .config("spark.driver.memory", "6g")
         .getOrCreate())

data = spark.read.parquet("yellow_tripdata_2024-12.parquet")
data.show()
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       2| 2024-12-01 00:12:27|  2024-12-01 00:31:12|              1|         9.76|         1|                 N|         138|          33|           1|       38.0|  6.0|    0.5|      4.72|         0.0|                  1.0|       51.97|                 0.0|       1.75|
# |       2| 2024-11-30 23:56:04|  2024-12-01 00:28:15|              1|         7.62|         1|                 N|         158|          42|           1|       37.3|  1.0|    0.5|      8.46|         0.0|                  1.0|       50.76|                 2.5|        0.0|
# |       2| 2024-12-01 00:50:35|  2024-12-01 01:24:46|              4|        20.07|         2|                 N|         132|         236|           2|       70.0|  0.0|    0.5|       0.0|        6.94|                  1.0|       82.69|                 2.5|       1.75|
# |       2| 2024-12-01 00:18:16|  2024-12-01 00:33:16|              3|         2.34|         1|                 N|         142|         186|           1|       15.6|  1.0|    0.5|      4.12|         0.0|                  1.0|       24.72|                 2.5|        0.0|
# |       2| 2024-12-01 00:56:13|  2024-12-01 01:18:25|              1|         5.05|         1|                 N|         107|          80|           1|       26.8|  1.0|    0.5|       5.0|         0.0|                  1.0|        36.8|                 2.5|        0.0|
# |       1| 2024-12-01 00:21:17|  2024-12-01 00:37:22|              1|          4.3|         1|                 N|         249|         141|           1|       20.5|  3.5|    0.5|       5.1|         0.0|                  1.0|        30.6|                 2.5|        0.0|
# |       2| 2024-12-01 00:04:53|  2024-12-01 00:31:03|              1|         7.66|         1|                 N|         186|          52|           1|       35.2|  1.0|    0.5|      8.04|         0.0|                  1.0|       48.24|                 2.5|        0.0|
# |       1| 2024-12-01 00:15:28|  2024-12-01 00:20:13|              1|          0.3|         1|                 N|         148|         148|           3|        5.8|  3.5|    0.5|       0.0|         0.0|                  1.0|        10.8|                 2.5|        0.0|
# |       1| 2024-12-01 00:38:54|  2024-12-01 01:03:46|              1|          9.4|         1|                 N|         234|         244|           1|       39.4|  3.5|    0.5|       0.0|         0.0|                  1.0|        44.4|                 2.5|        0.0|
# |       2| 2024-12-01 00:00:21|  2024-12-01 00:05:27|              2|         0.72|         1|                 N|         211|         231|           1|        7.2|  1.0|    0.5|      2.44|         0.0|                  1.0|       14.64|                 2.5|        0.0|
# |       2| 2024-12-01 00:07:13|  2024-12-01 00:20:57|              2|         3.54|         1|                 N|         231|          48|           1|       17.7|  1.0|    0.5|      4.54|         0.0|                  1.0|       27.24|                 2.5|        0.0|
# |       2| 2024-12-01 00:34:04|  2024-12-01 00:44:33|              1|         1.38|         1|                 N|          68|         137|           1|       10.7|  1.0|    0.5|       3.0|         0.0|                  1.0|        18.7|                 2.5|        0.0|
# |       2| 2024-12-01 00:57:27|  2024-12-01 01:00:44|              2|         0.45|         1|                 N|         230|         162|           2|        5.1|  1.0|    0.5|       0.0|         0.0|                  1.0|        10.1|                 2.5|        0.0|
# |       1| 2024-12-01 00:02:07|  2024-12-01 00:19:36|              3|          2.7|         1|                 N|         100|         239|           1|       17.7|  3.5|    0.5|       4.5|         0.0|                  1.0|        27.2|                 2.5|        0.0|
# |       2| 2024-12-01 00:07:12|  2024-12-01 00:07:25|              1|         0.03|         1|                 N|         262|         262|           4|       -3.0| -1.0|   -0.5|       0.0|         0.0|                 -1.0|        -8.0|                -2.5|        0.0|
# |       2| 2024-12-01 00:07:12|  2024-12-01 00:07:25|              1|         0.03|         1|                 N|         262|         140|           4|        3.0|  1.0|    0.5|       0.0|         0.0|                  1.0|         8.0|                 2.5|        0.0|
# |       2| 2024-12-01 00:30:37|  2024-12-01 00:33:50|              1|         0.48|         1|                 N|         237|         236|           1|        5.1|  1.0|    0.5|      2.02|         0.0|                  1.0|       12.12|                 2.5|        0.0|
# |       2| 2024-12-01 00:43:15|  2024-12-01 00:59:01|              1|         1.77|         1|                 N|         113|         249|           1|       14.9|  1.0|    0.5|       1.0|         0.0|                  1.0|        20.9|                 2.5|        0.0|
# |       1| 2024-12-01 00:03:22|  2024-12-01 00:16:23|              1|          2.1|         1|                 N|         142|         141|           1|       14.2|  3.5|    0.5|      1.92|         0.0|                  1.0|       21.12|                 2.5|        0.0|
# |       1| 2024-12-01 00:24:46|  2024-12-01 00:27:10|              1|          0.6|         1|                 N|         263|         263|           1|        5.1|  3.5|    0.5|      2.02|         0.0|                  1.0|       12.12|                 2.5|        0.0|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 20 rows

# %%
value_counts = data.groupBy("passenger_count").count()
value_counts.show()
# Out:
# +---------------+-------+
# |passenger_count|  count|
# +---------------+-------+
# |              0|  30397|
# |              7|      7|
# |              6|  14205|
# |              9|      2|
# |              5|  22283|
# |              1|2531706|
# |              3| 133727|
# |              8|      9|
# |              2| 507628|
# |              4| 102116|
# |           NULL| 326291|
# +---------------+-------+

# %% [markdown]
# Looking at this we observe a couple of things:
# 1. We have many null values which we are eliminating as are possibly wrong values inserted in the dataset
# 2. Also having over 30k 0 values shows that there might be a data entry error
# 3. Having very few samples of 6,7,8, and 9
#
# Conclusions:
#
# Add values of columns 6,7,8 and 9 will be sum as the standard sports of a car are 5 and we thing that by doing this we could catch up relation with customers asking for bigger cars.

# %% [markdown]
# # DATA CLEANING + FEATURE ENGINEERING

# %% [markdown]
# We have find out that the data might need some preprocessing as some columns might not follow a proper structure for the models we are attempting to implement.
#
# It is necessary to understand the dataset first. As we need to find out which columns might be relevant for building our predictions. Checking the dictionary of the dataset: https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf we have found this columns relevant to predict the tip_amount:
#
# - passenger_count: Number of passengers in the vehicle.
# - trip_distance: distance in miles.
# - PULocationID: Pickup point of the trip. It has numerical values, each one represents a different town.
# - DOLocationID: Drooff point of the trip. Follows the same range as PULocationID
# - fare_amount

# %% [markdown]
# ### EXPLANATION:
# - We have decided to substract from pickup_datetime and dropoff_datetime a column of trip_duration. By substracting dopoff and pickup times and dividing it to obtain the minutes which might be useful as the models could perform better with it.
# - We have also decided to create a column pickup_hour taken from the  column which we find it is one of the most relevant features as taxis have different fees depending on the hour.
# - A new column day_of_week is added stracting its values from pickup_datetime
# - In the sample print at the beginning of the notebook we have realized that there is one row which has negative values in columns that must be >=0 so we have decided to apply a filter for those cases.
# - For passenger count column we are adapting the range of values of columns 6,7,8 and 9. Now the value 6 will represent 6 or more passengers. This is tue the lack of samples of values 7,8 or 9 which could cause a little of confusion for our models.

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import unix_timestamp, hour, col, dayofweek, when

data = data.dropna(subset=["PULocationID", "DOLocationID","passenger_count", "trip_distance", "fare_amount", "tip_amount", "tpep_pickup_datetime", "tpep_dropoff_datetime"])


dataClean = data.filter((col("trip_distance") > 0) & (col("fare_amount") > 0) & (col("tip_amount") >= 0))
dataFeat = dataClean.withColumn("trip_duration", (unix_timestamp("tpep_dropoff_datetime") - unix_timestamp("tpep_pickup_datetime"))/60)

dataFeat = dataFeat.withColumn("passenger_count_grouped", when(col("passenger_count") >= 6, 6).otherwise(col("passenger_count")))

#As the range of values goes from 1-7 and we want it to start at 0, we substract 1.
dataFeat = dataFeat.withColumn("day_of_week", dayofweek("tpep_pickup_datetime")-1)
dataFeat = dataFeat.withColumn("pickup_hour",hour("tpep_pickup_datetime"))
dataFeat = dataFeat.dropna(subset=["trip_duration", "pickup_hour", "day_of_week"])

columns = ["passenger_count_grouped","trip_distance","PULocationID","DOLocationID","trip_duration", "pickup_hour", "tip_amount", "day_of_week"]
selectedData = dataFeat.select(columns)
selectedData.show()
# Out:
# +-----------------------+-------------+------------+------------+-------------------+-----------+----------+-----------+
# |passenger_count_grouped|trip_distance|PULocationID|DOLocationID|      trip_duration|pickup_hour|tip_amount|day_of_week|
# +-----------------------+-------------+------------+------------+-------------------+-----------+----------+-----------+
# |                      1|         9.76|         138|          33|              18.75|          0|      4.72|          0|
# |                      1|         7.62|         158|          42|  32.18333333333333|         23|      8.46|          6|
# |                      4|        20.07|         132|         236|  34.18333333333333|          0|       0.0|          0|
# |                      3|         2.34|         142|         186|               15.0|          0|      4.12|          0|
# |                      1|         5.05|         107|          80|               22.2|          0|       5.0|          0|
# |                      1|          4.3|         249|         141| 16.083333333333332|          0|       5.1|          0|
# |                      1|         7.66|         186|          52| 26.166666666666668|          0|      8.04|          0|
# |                      1|          0.3|         148|         148|               4.75|          0|       0.0|          0|
# |                      1|          9.4|         234|         244| 24.866666666666667|          0|       0.0|          0|
# |                      2|         0.72|         211|         231|                5.1|          0|      2.44|          0|
# |                      2|         3.54|         231|          48| 13.733333333333333|          0|      4.54|          0|
# |                      1|         1.38|          68|         137| 10.483333333333333|          0|       3.0|          0|
# |                      2|         0.45|         230|         162|  3.283333333333333|          0|       0.0|          0|
# |                      3|          2.7|         100|         239| 17.483333333333334|          0|       4.5|          0|
# |                      1|         0.03|         262|         140|0.21666666666666667|          0|       0.0|          0|
# |                      1|         0.48|         237|         236|  3.216666666666667|          0|      2.02|          0|
# |                      1|         1.77|         113|         249| 15.766666666666667|          0|       1.0|          0|
# |                      1|          2.1|         142|         141| 13.016666666666667|          0|      1.92|          0|
# |                      1|          0.6|         263|         263|                2.4|          0|      2.02|          0|
# |                      1|          1.8|         140|         163| 10.483333333333333|          0|       0.0|          0|
# +-----------------------+-------------+------------+------------+-------------------+-----------+----------+-----------+
# only showing top 20 rows

# %%
value_counts = selectedData.groupBy("passenger_count_grouped").count()
value_counts.show()
# Out:
# +-----------------------+-------+
# |passenger_count_grouped|  count|
# +-----------------------+-------+
# |                      0|  29150|
# |                      6|  14091|
# |                      5|  22057|
# |                      1|2450879|
# |                      3| 128633|
# |                      2| 489550|
# |                      4|  95171|
# +-----------------------+-------+

# %% [markdown]
# ## CATEGORICAL COLUMNS(INDEXERS AND ENCODERS)

# %% [markdown]
# To handle categorical columns we are using StringIndexer. As each value in the column represents a town in NYC and this can cause problems as for example zone 100 is not twice good as zone 50, are just different places.
#
# For this StringIndexer is designed to convert a column of labels into a column of label indices.
#
# The same methodology is applied for columns day_of_week pickup_hour and passenger_count_grouped

# %%
indexer_pickup = StringIndexer(inputCol="PULocationID", outputCol="PULocationID_index", handleInvalid="keep")
indexer_dropoff = StringIndexer(inputCol="DOLocationID", outputCol="DOLocationID_index", handleInvalid="keep")

encoder_pickup = OneHotEncoder(inputCols=["PULocationID_index"], outputCols=["PULocationID_vec"], dropLast=False, handleInvalid="keep")
encoder_drop = OneHotEncoder(inputCols=["DOLocationID_index"], outputCols=["DOLocationID_vec"], dropLast=False, handleInvalid="keep")

indexer_day = StringIndexer(inputCol="day_of_week", outputCol="day_of_week_index", handleInvalid="keep")
indexer_hour = StringIndexer(inputCol="pickup_hour", outputCol="pickup_hour_index", handleInvalid="keep")
indexer_pass = StringIndexer(inputCol="passenger_count_grouped", outputCol="passenger_count_index", handleInvalid="keep")

encoder_day = OneHotEncoder(inputCols=["day_of_week_index"], outputCols=["day_of_week_vec"], dropLast=True)
encoder_hour = OneHotEncoder(inputCols=["pickup_hour_index"], outputCols=["pickup_hour_vec"], dropLast=True)
encoder_pass = OneHotEncoder(inputCols=["passenger_count_index"], outputCols=["passenger_count_vec"], dropLast=True)

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# ## MODEL TRAINING (LINEAR REGRESSION)

# %% [markdown]
# The steps we are following in order to train the different models are:
#
# 1. VectorAssembler: We have combined various ride details like trip_distance, fare_amount, and vectorized locations (PULocationID_vec, DOLocationID_vec), time (day_of_week_vec, pickup_hour_vec), and passenger count (passenger_count_vec) into one 'features' input for my model.
#
# 2. LinearRegression (lr): We have set up a Linear Regression model to learn how to predict the tip_amount based on that combined features vector.
#
# 3. ParamGridBuilder (paramGrid): We have defined a set of different tuning parameters (like regularization) for my Linear Regression, so I can test which combination works best.
#
# 4. RegressionEvaluator (evaluator): This will measure how good my model is by calculating the Mean Absolute Error (MAE) between its prediction and the actual tip_amount.
#
# 5. Pipeline: We have chained all my data prep steps (indexing, encoding, assembling) and the Linear Regression model into a single, streamlined workflow.
#
# 6. CrossValidator (cv): This tool will automatically train and test of our pipeline with all the different parameter sets from paramGrid using 3-fold cross-validation, picking the best one based on the MAE.
#
# 7. Data Sampling & Splitting: We have sampled 20% of the data (as in first stage the model took a vast amount of time to train) and then split it into dataTrain (for training/cross-validation) and dataTest (for final, unseen evaluation) to speed things up and properly assess performance.
#
# 8. Final Evaluation: After cv.fit(dataTrain) finds the best model (cvModel), We use it to make predictions on the dataTest. Then, We calculate MAE, RMSE, MSE, and R2 to see how well this final model performs on completely new data.

# %% [markdown]
# We use a VectorAssembler to combine relevant features into a single vector for the model.

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.regression import LinearRegression, RandomForestRegressor
from pyspark.ml.pipeline import Pipeline

assemblerCols = ["trip_distance","PULocationID_vec","DOLocationID_vec","trip_duration", "day_of_week_vec", "pickup_hour_vec", "passenger_count_vec"
]

assembler = VectorAssembler(inputCols=assemblerCols, outputCol='features')

# %% [markdown]
# We set up the Linear Regression model and create a pipeline that includes all preprocessing steps and the model itself.

# %%
lr = LinearRegression(labelCol="tip_amount", featuresCol="features")
paramGrid = (ParamGridBuilder().addGrid(lr.regParam,[0.01,0.1,0.5])
             .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])
             .addGrid(lr.maxIter, [50, 100])
             .build())

evaluator = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mae')
pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, lr
])

# %% [markdown]
# We use cross-validation to tune hyperparameters and split the data for training and testing.

# %%
cv = CrossValidator(estimator=pipeline, estimatorParamMaps=paramGrid, evaluator=evaluator, numFolds=3, parallelism=2)

sampledData = selectedData.sample(withReplacement=False, fraction=0.2, seed=42)
dataTrain, dataTest = sampledData.randomSplit([0.8,0.2], seed=42)
dataTrain.show()
# Out:
# +-----------------------+-------------+------------+------------+------------------+-----------+----------+-----------+
# |passenger_count_grouped|trip_distance|PULocationID|DOLocationID|     trip_duration|pickup_hour|tip_amount|day_of_week|
# +-----------------------+-------------+------------+------------+------------------+-----------+----------+-----------+
# |                      0|          0.1|          48|          48|0.6666666666666666|          6|       0.0|          4|
# |                      0|          0.1|         186|         164|              10.2|         18|       2.8|          6|
# |                      0|          0.1|         262|         262|              0.65|         18|       0.0|          5|
# |                      0|          0.1|         265|         265|0.5333333333333333|          0|       0.0|          5|
# |                      0|          0.2|         100|         164|               5.0|         10|       2.1|          6|
# |                      0|          0.2|         138|         138|1.1833333333333333|         14|       0.0|          0|
# |                      0|          0.2|         162|         229|1.2666666666666666|          9|       0.0|          1|
# |                      0|          0.2|         239|         239|2.8833333333333333|         11|       0.0|          4|
# |                      0|          0.2|         246|         246|1.7833333333333334|         15|       0.0|          1|
# |                      0|          0.2|         249|         249|               2.1|         13|       0.0|          4|
# |                      0|          0.2|         262|         262|              1.75|         13|       0.0|          0|
# |                      0|          0.3|          43|         163|1.8333333333333333|         11|       2.0|          0|
# |                      0|          0.3|          68|          48|12.916666666666666|         18|       0.0|          5|
# |                      0|          0.3|          68|         100|               5.4|         10|       0.0|          5|
# |                      0|          0.3|          68|         186| 4.866666666666666|         14|       2.0|          0|
# |                      0|          0.3|         141|         141|1.5333333333333334|         15|       0.0|          3|
# |                      0|          0.3|         141|         237|               3.8|         18|      2.45|          5|
# |                      0|          0.3|         141|         237|              4.45|         16|       0.0|          0|
# |                      0|          0.3|         143|         143|1.5333333333333334|         19|       0.0|          1|
# |                      0|          0.3|         159|         159|1.6666666666666667|          7|       0.0|          0|
# +-----------------------+-------------+------------+------------+------------------+-----------+----------+-----------+
# only showing top 20 rows

# %% [markdown]
# Fit the cross-validated pipeline on the training data, make predictions, and compute evaluation metrics.

# %%
cvModel = cv.fit(dataTrain)

predictions = cvModel.transform(dataTest)
mae = evaluator.evaluate(predictions)
print("MAE:", mae)

rmse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='rmse')
rmse = rmse_eval.evaluate(predictions)
print("RMSE:",rmse)

mse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mse')
mse = mse_eval.evaluate(predictions)
print("MSE:",mse)

r2_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_evaluator.evaluate(predictions)
print("R2:", r2)
# Out:
# MAE: 2.149131881325228
# RMSE: 3.359277072196714
# MSE: 11.284742447786527
# R2: 0.34394445866483747

# %% [markdown]
# ### RESULTS:
#
# Linear Regression provides a simple baseline model. With an R² score of 0.34, it explains approximately 34% of the variance in the target variable. This indicates that it may struggle to model complex patterns in the data. While it's not highly accurate, its interpretability and speed make it a reasonable starting point for regression problems.
#
# ### POSSIBLE IMPROVEMENTS:
#
# After some testing how adding more columns (like: pickup_hour, day_of_week,
#     is_night, is_weekend) could increase or decrease our model performance. The results obtained were worse, then we concluded leaving they are now, the other results obtained are:
#
# MAE on Test data: 2.1867288596114304
# RMSE on Test Data: 3.5895547766976675
# MSE on Test Data: 12.365532960156768

# %% [markdown]
# ## DECISION TREE REGRESSOR

# %% [markdown]
# Decision Trees can capture non-linear relationships and interactions between features. Here, we use a Decision Tree Regressor to predict tip amounts.

# %% [markdown]
# Set up the Decision Tree model and create a pipeline with relevant preprocessing steps.

# %%
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
dt = DecisionTreeRegressor(featuresCol="features", labelCol="tip_amount", seed=42)

paramGridDT = (ParamGridBuilder()
               .addGrid(dt.maxDepth, [5, 10, 15]).addGrid(dt.maxBins, [32,64])
               .build())

assemblerDecTree = VectorAssembler(
    inputCols=[
        "trip_distance", "trip_duration", "pickup_hour",
        "day_of_week_vec",
        "PULocationID_vec", "DOLocationID_vec"
    ],
    outputCol="features"
)
pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day,
    encoder_pickup, encoder_drop,
    encoder_day,
    assemblerDecTree,
    dt
])
evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")

cvDT = CrossValidator(estimator=pipeline,
                      estimatorParamMaps=paramGridDT,
                      evaluator=evaluator,
                      numFolds=3)

# %% [markdown]
# Fit the model, make predictions, and compute evaluation metrics.

# %%
modelDT = cvDT.fit(dataTrain)
predictions = modelDT.transform(dataTest)

mae = evaluator.evaluate(predictions)
rsme_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="rmse")
r2_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
mse_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mse")

print("MAE:", mae)
print("RMSE:", rsme_evaluator.evaluate(predictions))
print("MSE:", mse_evaluator.evaluate(predictions))
print("R2:", r2_evaluator.evaluate(predictions))
# Out:
# 25/05/20 22:58:34 WARN DAGScheduler: Broadcasting large task binary with size 1031.5 KiB
# 25/05/20 22:58:40 WARN DAGScheduler: Broadcasting large task binary with size 1086.8 KiB
# 25/05/20 22:59:00 WARN DAGScheduler: Broadcasting large task binary with size 1058.3 KiB
# 25/05/20 22:59:06 WARN DAGScheduler: Broadcasting large task binary with size 1053.0 KiB
# MAE: 2.0265963049153024
# RMSE: 3.220148866862463
# MSE: 10.369358724755607
# R2: 0.3971616735654967

# %% [markdown]
# ### RESULTS
#
# The Decision Tree model improves on Linear Regression in terms of all metrics, particularly showing a better fit with a slightly higher R² score (0.39). This suggests that it captures non-linear patterns more effectively, though it may be prone to overfitting without pruning or depth control.

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %% [markdown]
# Random Forests are ensembles of decision trees that improve predictive performance and reduce overfitting. Here, we use a Random Forest Regressor for tip prediction.

# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline

rf = RandomForestRegressor(featuresCol="features", labelCol="tip_amount")

paramGridRF = (ParamGridBuilder()
               .addGrid(rf.numTrees, [10, 20])
               .addGrid(rf.maxDepth, [5, 10])
               .build())

pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, rf
])
evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")

cvRF = CrossValidator(estimator=pipeline,
                      estimatorParamMaps=paramGridRF,
                      evaluator=evaluator,
                      numFolds=3,
                      parallelism=2)

# %% [markdown]
# For this model, we are using a sample in order to reduce the training times.

# %%
sampledData = selectedData.sample(withReplacement=False, fraction=0.2, seed=42)

# %% [markdown]
# Fit the model, make predictions, and compute evaluation metrics.

# %%
cvModelRF = cvRF.fit(dataTrain)
predRF = cvModelRF.transform(dataTest)

evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")
print("MAE:", evaluator.evaluate(predRF))

rmse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='rmse')
rmse = rmse_eval.evaluate(predRF)
print("RMSE:",rmse)

mse_eval = RegressionEvaluator(labelCol='tip_amount', predictionCol='prediction', metricName='mse')
mse = mse_eval.evaluate(predRF)
print(f"MSE:",mse)

r2_evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_evaluator.evaluate(predRF)
print("R2:", r2)
# Out:
# 25/05/20 22:59:27 WARN DAGScheduler: Broadcasting large task binary with size 1415.0 KiB
# 25/05/20 22:59:28 WARN DAGScheduler: Broadcasting large task binary with size 2003.8 KiB
# 25/05/20 22:59:38 WARN DAGScheduler: Broadcasting large task binary with size 1176.0 KiB
# 25/05/20 22:59:40 WARN DAGScheduler: Broadcasting large task binary with size 1778.8 KiB
# 25/05/20 22:59:41 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/20 22:59:43 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/05/20 22:59:53 WARN DAGScheduler: Broadcasting large task binary with size 1015.8 KiB
# 25/05/20 22:59:55 WARN DAGScheduler: Broadcasting large task binary with size 1476.5 KiB
# 25/05/20 22:59:56 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
# 25/05/20 23:00:06 WARN DAGScheduler: Broadcasting large task binary with size 1162.1 KiB
# 25/05/20 23:00:08 WARN DAGScheduler: Broadcasting large task binary with size 1774.2 KiB
# 25/05/20 23:00:09 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/05/20 23:00:11 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/05/20 23:00:22 WARN DAGScheduler: Broadcasting large task binary with size 1035.7 KiB
# 25/05/20 23:00:24 WARN DAGScheduler: Broadcasting large task binary with size 1472.8 KiB
# 25/05/20 23:00:25 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 25/05/20 23:00:36 WARN DAGScheduler: Broadcasting large task binary with size 1193.9 KiB
# 25/05/20 23:00:37 WARN DAGScheduler: Broadcasting large task binary with size 1825.9 KiB
# 25/05/20 23:00:39 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/05/20 23:00:41 WARN DAGScheduler: Broadcasting large task binary with size 3.9 MiB
# 25/05/20 23:00:56 WARN DAGScheduler: Broadcasting large task binary with size 1030.4 KiB
# 25/05/20 23:00:57 WARN DAGScheduler: Broadcasting large task binary with size 1531.5 KiB
# 25/05/20 23:00:59 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# MAE: 2.0483346781582537
# RMSE: 3.2245523545605392
# MSE: 10.397737887301918
# R2: 0.39551180810041375

# %% [markdown]
# ### RESULTS
#
# Random Forest performs nearly identically to the Decision Tree in terms of error and variance explained. However, as an ensemble method, it typically generalizes better and reduces overfitting by averaging across many trees, making it a more stable and reliable option in practice.

# %% [markdown]
# ## Gradient-Boosted Tree Regressor

# %% [markdown]
# Gradient-Boosted Trees build an ensemble of trees sequentially, each correcting the errors of the previous one. This often leads to strong predictive performance.

# %% [markdown]
# Set up the GBT model and create a pipeline with all preprocessing steps.

# %%
from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(labelCol="tip_amount", featuresCol="features", maxIter=30)

paramGrid = (ParamGridBuilder()
    .addGrid(gbt.maxDepth, [5, 7])
    .addGrid(gbt.maxIter, [50, 100])
    .addGrid(gbt.stepSize, [0.1, 0.2])
    .build())

evaluator = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mae")

pipeline = Pipeline(stages=[
    indexer_pickup, indexer_dropoff,
    indexer_day, indexer_hour, indexer_pass,
    encoder_pickup, encoder_drop,
    encoder_day, encoder_hour, encoder_pass,
    assembler, gbt
])

cv = CrossValidator(
    estimator=pipeline,
    estimatorParamMaps=paramGrid,
    evaluator=evaluator,
    numFolds=3,
    parallelism=2
)

# %% [markdown]
# Fit the model, make predictions, and compute evaluation metrics.

# %%
cvModel = cv.fit(dataTrain)

predictions = cvModel.transform(dataTest)

mae = evaluator.evaluate(predictions)
print("MAE:", mae)

rmse_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="rmse")
rmse = rmse_eval.evaluate(predictions)
print("RMSE:", rmse)

mse_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="mse")
mse = mse_eval.evaluate(predictions)
print("MSE:", mse)

r2_eval = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName="r2")
r2 = r2_eval.evaluate(predictions)
print("R2:", r2)
# Out:
# 25/05/20 23:01:17 WARN BlockManager: Asked to remove block rdd_16381_4, which does not exist
# 25/05/20 23:01:24 WARN BlockManager: Asked to remove block rdd_16567_13, which does not exist
# 25/05/20 23:01:24 WARN BlockManager: Asked to remove block rdd_16567_6, which does not exist
# 25/05/20 23:02:27 WARN BlockManager: Asked to remove block rdd_18840_12, which does not exist
# 25/05/20 23:02:27 WARN BlockManager: Asked to remove block rdd_18840_9, which does not exist
# 25/05/20 23:02:27 WARN BlockManager: Asked to remove block rdd_18840_11, which does not exist
# 25/05/20 23:02:27 WARN BlockManager: Asked to remove block rdd_18840_13, which does not exist
# 25/05/20 23:02:27 WARN BlockManager: Asked to remove block rdd_18840_6, which does not exist
# 25/05/20 23:02:55 WARN BlockManager: Asked to remove block rdd_19808_12, which does not exist
# 25/05/20 23:02:55 WARN BlockManager: Asked to remove block rdd_19808_7, which does not exist
# 25/05/20 23:02:55 WARN BlockManager: Asked to remove block rdd_19808_2, which does not exist
# 25/05/20 23:03:04 WARN BlockManager: Asked to remove block rdd_20116_14, which does not exist
# 25/05/20 23:03:04 WARN BlockManager: Asked to remove block rdd_20116_7, which does not exist
# 25/05/20 23:03:04 WARN BlockManager: Asked to remove block rdd_20116_10, which does not exist
# 25/05/20 23:03:49 WARN BlockManager: Asked to remove block rdd_21656_13, which does not exist
# 25/05/20 23:03:49 WARN BlockManager: Asked to remove block rdd_21656_6, which does not exist
# 25/05/20 23:03:49 WARN BlockManager: Asked to remove block rdd_21656_10, which does not exist
# 25/05/20 23:03:49 WARN BlockManager: Asked to remove block rdd_21656_3, which does not exist
# 25/05/20 23:03:51 WARN BlockManager: Asked to remove block rdd_21744_7, which does not exist
# 25/05/20 23:03:51 WARN BlockManager: Asked to remove block rdd_21744_5, which does not exist
# 25/05/20 23:03:54 WARN BlockManager: Asked to remove block rdd_21832_6, which does not exist
# 25/05/20 23:04:45 WARN BlockManager: Asked to remove block rdd_23488_6, which does not exist
# 25/05/20 23:04:45 WARN BlockManager: Asked to remove block rdd_23488_13, which does not exist
# 25/05/20 23:04:45 WARN BlockManager: Asked to remove block rdd_23488_1, which does not exist
# 25/05/20 23:05:49 WARN BlockManager: Asked to remove block rdd_25389_14, which does not exist
# 25/05/20 23:05:49 WARN BlockManager: Asked to remove block rdd_25389_6, which does not exist
# 25/05/20 23:06:47 WARN BlockManager: Asked to remove block rdd_27163_6, which does not exist
# 25/05/20 23:06:47 WARN BlockManager: Asked to remove block rdd_27163_5, which does not exist
# 25/05/20 23:07:34 WARN BlockManager: Asked to remove block broadcast_13456, which does not exist
# 25/05/20 23:07:56 WARN DAGScheduler: Broadcasting large task binary with size 1000.2 KiB
# 25/05/20 23:07:57 WARN DAGScheduler: Broadcasting large task binary with size 1001.0 KiB
# 25/05/20 23:07:57 WARN DAGScheduler: Broadcasting large task binary with size 1002.9 KiB
# 25/05/20 23:07:57 WARN DAGScheduler: Broadcasting large task binary with size 1005.7 KiB
# 25/05/20 23:07:58 WARN DAGScheduler: Broadcasting large task binary with size 1007.6 KiB
# 25/05/20 23:07:58 WARN DAGScheduler: Broadcasting large task binary with size 1008.1 KiB
# 25/05/20 23:07:58 WARN DAGScheduler: Broadcasting large task binary with size 1008.9 KiB
# 25/05/20 23:07:58 WARN DAGScheduler: Broadcasting large task binary with size 1009.9 KiB
# 25/05/20 23:07:59 WARN DAGScheduler: Broadcasting large task binary with size 1012.2 KiB
# 25/05/20 23:07:59 WARN DAGScheduler: Broadcasting large task binary with size 1015.4 KiB
# 25/05/20 23:07:59 WARN DAGScheduler: Broadcasting large task binary with size 1019.7 KiB
# 25/05/20 23:07:59 WARN DAGScheduler: Broadcasting large task binary with size 1021.0 KiB
# 25/05/20 23:08:00 WARN DAGScheduler: Broadcasting large task binary with size 1021.5 KiB
# 25/05/20 23:08:00 WARN DAGScheduler: Broadcasting large task binary with size 1022.3 KiB
# 25/05/20 23:08:00 WARN DAGScheduler: Broadcasting large task binary with size 1023.3 KiB
# 25/05/20 23:08:00 WARN DAGScheduler: Broadcasting large task binary with size 1025.7 KiB
# 25/05/20 23:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1029.3 KiB
# 25/05/20 23:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1034.5 KiB
# 25/05/20 23:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1035.3 KiB
# 25/05/20 23:08:01 WARN DAGScheduler: Broadcasting large task binary with size 1000.6 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1035.8 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1001.7 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1036.6 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1003.9 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1037.6 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1007.5 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1039.1 KiB
# 25/05/20 23:08:02 WARN DAGScheduler: Broadcasting large task binary with size 1012.4 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1041.5 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1012.9 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1044.0 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1013.4 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1045.0 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1014.2 KiB
# 25/05/20 23:08:03 WARN DAGScheduler: Broadcasting large task binary with size 1045.5 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1015.3 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1046.1 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1017.0 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1047.0 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1019.1 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1048.6 KiB
# 25/05/20 23:08:04 WARN DAGScheduler: Broadcasting large task binary with size 1021.6 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1051.3 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1022.6 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1056.1 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1023.1 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1057.5 KiB
# 25/05/20 23:08:05 WARN DAGScheduler: Broadcasting large task binary with size 1023.9 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1058.0 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1025.0 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1058.8 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1027.3 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1059.8 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1030.6 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1061.4 KiB
# 25/05/20 23:08:06 WARN DAGScheduler: Broadcasting large task binary with size 1035.4 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1063.6 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1036.5 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1066.9 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1037.0 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1068.4 KiB
# 25/05/20 23:08:07 WARN DAGScheduler: Broadcasting large task binary with size 1037.8 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1068.9 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1038.9 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1069.6 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1040.5 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1070.8 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1043.5 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1072.7 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1048.2 KiB
# 25/05/20 23:08:08 WARN DAGScheduler: Broadcasting large task binary with size 1076.3 KiB
# 25/05/20 23:08:09 WARN DAGScheduler: Broadcasting large task binary with size 1049.2 KiB
# 25/05/20 23:08:09 WARN DAGScheduler: Broadcasting large task binary with size 1081.1 KiB
# 25/05/20 23:08:09 WARN DAGScheduler: Broadcasting large task binary with size 1049.8 KiB
# 25/05/20 23:08:09 WARN DAGScheduler: Broadcasting large task binary with size 1082.1 KiB
# 25/05/20 23:08:09 WARN DAGScheduler: Broadcasting large task binary with size 1050.5 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1082.6 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1051.3 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1083.3 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1052.9 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1084.4 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1055.6 KiB
# 25/05/20 23:08:10 WARN DAGScheduler: Broadcasting large task binary with size 1086.3 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1059.2 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1089.1 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1060.3 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1093.5 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1060.8 KiB
# 25/05/20 23:08:11 WARN DAGScheduler: Broadcasting large task binary with size 1095.7 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1061.5 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1096.2 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1062.6 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1097.0 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1064.9 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1097.7 KiB
# 25/05/20 23:08:12 WARN DAGScheduler: Broadcasting large task binary with size 1068.4 KiB
# 25/05/20 23:08:13 WARN DAGScheduler: Broadcasting large task binary with size 1099.6 KiB
# 25/05/20 23:08:13 WARN DAGScheduler: Broadcasting large task binary with size 1073.5 KiB
# 25/05/20 23:08:13 WARN DAGScheduler: Broadcasting large task binary with size 1101.7 KiB
# 25/05/20 23:08:13 WARN DAGScheduler: Broadcasting large task binary with size 1074.7 KiB
# 25/05/20 23:08:13 WARN DAGScheduler: Broadcasting large task binary with size 1105.0 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1075.2 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1105.5 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1075.8 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1106.0 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1076.7 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1106.7 KiB
# 25/05/20 23:08:14 WARN DAGScheduler: Broadcasting large task binary with size 1077.9 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1107.8 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1079.8 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1109.7 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1082.5 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1112.7 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1083.8 KiB
# 25/05/20 23:08:15 WARN DAGScheduler: Broadcasting large task binary with size 1117.6 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1084.3 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1118.2 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1085.1 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1118.7 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1086.2 KiB
# 25/05/20 23:08:16 WARN DAGScheduler: Broadcasting large task binary with size 1119.5 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1088.2 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1120.5 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1091.3 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1122.5 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1096.7 KiB
# 25/05/20 23:08:17 WARN DAGScheduler: Broadcasting large task binary with size 1125.5 KiB
# 25/05/20 23:08:18 WARN DAGScheduler: Broadcasting large task binary with size 1098.5 KiB
# 25/05/20 23:08:18 WARN DAGScheduler: Broadcasting large task binary with size 1130.0 KiB
# 25/05/20 23:08:18 WARN DAGScheduler: Broadcasting large task binary with size 1099.0 KiB
# 25/05/20 23:08:18 WARN DAGScheduler: Broadcasting large task binary with size 1131.5 KiB
# 25/05/20 23:08:18 WARN DAGScheduler: Broadcasting large task binary with size 1099.8 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1132.0 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1100.9 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1132.8 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1103.3 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1133.8 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1106.6 KiB
# 25/05/20 23:08:19 WARN DAGScheduler: Broadcasting large task binary with size 1136.0 KiB
# 25/05/20 23:08:20 WARN DAGScheduler: Broadcasting large task binary with size 1111.4 KiB
# 25/05/20 23:08:20 WARN DAGScheduler: Broadcasting large task binary with size 1139.4 KiB
# 25/05/20 23:08:20 WARN DAGScheduler: Broadcasting large task binary with size 1111.9 KiB
# 25/05/20 23:08:20 WARN DAGScheduler: Broadcasting large task binary with size 1144.4 KiB
# 25/05/20 23:08:20 WARN DAGScheduler: Broadcasting large task binary with size 1112.4 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1145.3 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1113.1 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1145.8 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1114.2 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1146.4 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1116.6 KiB
# 25/05/20 23:08:21 WARN DAGScheduler: Broadcasting large task binary with size 1147.3 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1120.3 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1149.2 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1126.0 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1152.2 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1127.6 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1156.5 KiB
# 25/05/20 23:08:22 WARN DAGScheduler: Broadcasting large task binary with size 1128.1 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1156.8 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1128.9 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1157.4 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1129.9 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1158.1 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1131.7 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1159.2 KiB
# 25/05/20 23:08:23 WARN DAGScheduler: Broadcasting large task binary with size 1134.1 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1161.5 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1137.6 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1165.0 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1138.3 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1169.1 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1138.8 KiB
# 25/05/20 23:08:24 WARN DAGScheduler: Broadcasting large task binary with size 1170.3 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1139.5 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1170.9 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1140.6 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1171.6 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1142.8 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1172.6 KiB
# 25/05/20 23:08:25 WARN DAGScheduler: Broadcasting large task binary with size 1146.1 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1174.8 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1149.7 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1177.2 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1151.0 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1180.2 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1151.6 KiB
# 25/05/20 23:08:26 WARN DAGScheduler: Broadcasting large task binary with size 1180.6 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1152.3 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1181.1 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1153.5 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1181.9 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1155.8 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1182.9 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1159.4 KiB
# 25/05/20 23:08:27 WARN DAGScheduler: Broadcasting large task binary with size 1185.2 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1165.0 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1188.8 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1165.7 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1193.5 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1166.2 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1193.9 KiB
# 25/05/20 23:08:28 WARN DAGScheduler: Broadcasting large task binary with size 1167.0 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1194.4 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1168.1 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1195.2 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1170.0 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1196.3 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1173.2 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1198.4 KiB
# 25/05/20 23:08:29 WARN DAGScheduler: Broadcasting large task binary with size 1177.5 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1201.7 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1178.2 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1206.1 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1178.7 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1206.8 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1179.5 KiB
# 25/05/20 23:08:30 WARN DAGScheduler: Broadcasting large task binary with size 1207.3 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1180.3 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1208.0 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1182.1 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1209.2 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1185.2 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1211.0 KiB
# 25/05/20 23:08:31 WARN DAGScheduler: Broadcasting large task binary with size 1189.6 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1213.6 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1190.1 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1217.0 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1190.6 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1218.1 KiB
# 25/05/20 23:08:32 WARN DAGScheduler: Broadcasting large task binary with size 1191.2 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1218.6 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1192.1 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1219.4 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1193.7 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1220.4 KiB
# 25/05/20 23:08:33 WARN DAGScheduler: Broadcasting large task binary with size 1195.5 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1222.6 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1197.7 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1226.4 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1199.1 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1231.7 KiB
# 25/05/20 23:08:34 WARN DAGScheduler: Broadcasting large task binary with size 1199.6 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1231.5 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1200.4 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1232.0 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1201.4 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1232.8 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1202.8 KiB
# 25/05/20 23:08:35 WARN DAGScheduler: Broadcasting large task binary with size 1233.6 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1205.3 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1235.4 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1209.2 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1238.1 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1210.7 KiB
# 25/05/20 23:08:36 WARN DAGScheduler: Broadcasting large task binary with size 1242.3 KiB
# 25/05/20 23:08:37 WARN DAGScheduler: Broadcasting large task binary with size 1211.2 KiB
# 25/05/20 23:08:37 WARN DAGScheduler: Broadcasting large task binary with size 1243.6 KiB
# 25/05/20 23:08:37 WARN DAGScheduler: Broadcasting large task binary with size 1211.9 KiB
# 25/05/20 23:08:37 WARN DAGScheduler: Broadcasting large task binary with size 1244.1 KiB
# 25/05/20 23:08:37 WARN DAGScheduler: Broadcasting large task binary with size 1212.7 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1244.9 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1214.7 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1245.9 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1217.7 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1247.8 KiB
# 25/05/20 23:08:38 WARN DAGScheduler: Broadcasting large task binary with size 1222.0 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1250.6 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1223.0 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1254.2 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1223.5 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1254.8 KiB
# 25/05/20 23:08:39 WARN DAGScheduler: Broadcasting large task binary with size 1224.3 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1255.3 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1225.4 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1256.0 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1227.5 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1257.2 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1231.1 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1259.5 KiB
# 25/05/20 23:08:40 WARN DAGScheduler: Broadcasting large task binary with size 1235.9 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1263.2 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1236.4 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1268.9 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1236.9 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1270.4 KiB
# 25/05/20 23:08:41 WARN DAGScheduler: Broadcasting large task binary with size 1237.7 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1270.9 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1238.8 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1271.7 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1240.9 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1272.5 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1244.6 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1274.3 KiB
# 25/05/20 23:08:42 WARN DAGScheduler: Broadcasting large task binary with size 1250.3 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1277.1 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1251.6 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1280.9 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1252.1 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1281.5 KiB
# 25/05/20 23:08:43 WARN DAGScheduler: Broadcasting large task binary with size 1252.8 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1253.9 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1282.1 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1256.3 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1282.8 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1259.1 KiB
# 25/05/20 23:08:44 WARN DAGScheduler: Broadcasting large task binary with size 1283.8 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1263.0 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1285.7 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1263.4 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1289.3 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1294.1 KiB
# 25/05/20 23:08:45 WARN DAGScheduler: Broadcasting large task binary with size 1264.0 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1264.7 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1294.5 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1265.8 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1295.0 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1267.7 KiB
# 25/05/20 23:08:46 WARN DAGScheduler: Broadcasting large task binary with size 1295.8 KiB
# 25/05/20 23:08:47 WARN DAGScheduler: Broadcasting large task binary with size 1271.0 KiB
# 25/05/20 23:08:47 WARN DAGScheduler: Broadcasting large task binary with size 1296.9 KiB
# 25/05/20 23:08:47 WARN DAGScheduler: Broadcasting large task binary with size 1276.5 KiB
# 25/05/20 23:08:47 WARN DAGScheduler: Broadcasting large task binary with size 1299.0 KiB
# 25/05/20 23:08:47 WARN DAGScheduler: Broadcasting large task binary with size 1278.9 KiB
# 25/05/20 23:08:48 WARN DAGScheduler: Broadcasting large task binary with size 1302.5 KiB
# 25/05/20 23:08:48 WARN DAGScheduler: Broadcasting large task binary with size 1279.4 KiB
# 25/05/20 23:08:48 WARN DAGScheduler: Broadcasting large task binary with size 1306.2 KiB
# 25/05/20 23:08:48 WARN DAGScheduler: Broadcasting large task binary with size 1280.0 KiB
# 25/05/20 23:08:48 WARN DAGScheduler: Broadcasting large task binary with size 1306.0 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1281.0 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1306.5 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1282.2 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1307.3 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1284.3 KiB
# 25/05/20 23:08:49 WARN DAGScheduler: Broadcasting large task binary with size 1308.5 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1286.8 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1310.3 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1288.1 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1312.8 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1288.6 KiB
# 25/05/20 23:08:50 WARN DAGScheduler: Broadcasting large task binary with size 1316.3 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1289.2 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1317.2 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1290.1 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1317.7 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1291.1 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1318.5 KiB
# 25/05/20 23:08:51 WARN DAGScheduler: Broadcasting large task binary with size 1292.5 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1319.6 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1294.6 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1321.8 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1296.2 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1324.9 KiB
# 25/05/20 23:08:52 WARN DAGScheduler: Broadcasting large task binary with size 1296.8 KiB
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1329.3 KiB
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1297.5 KiB
# 25/05/20 23:08:53 WARN BlockManager: Asked to remove block rdd_30694_0, which does not exist
# 25/05/20 23:08:53 WARN BlockManager: Asked to remove block rdd_30694_5, which does not exist
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1330.6 KiB
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1298.4 KiB
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1331.1 KiB
# 25/05/20 23:08:53 WARN DAGScheduler: Broadcasting large task binary with size 1300.1 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1331.9 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1302.5 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1333.0 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1305.4 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1334.6 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1306.6 KiB
# 25/05/20 23:08:54 WARN DAGScheduler: Broadcasting large task binary with size 1337.5 KiB
# 25/05/20 23:08:55 WARN DAGScheduler: Broadcasting large task binary with size 1307.2 KiB
# 25/05/20 23:08:55 WARN DAGScheduler: Broadcasting large task binary with size 1341.7 KiB
# 25/05/20 23:08:55 WARN DAGScheduler: Broadcasting large task binary with size 1307.9 KiB
# 25/05/20 23:08:55 WARN DAGScheduler: Broadcasting large task binary with size 1342.6 KiB
# 25/05/20 23:08:55 WARN DAGScheduler: Broadcasting large task binary with size 1308.4 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1343.1 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1309.2 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1343.9 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1310.3 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1344.9 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1311.5 KiB
# 25/05/20 23:08:56 WARN DAGScheduler: Broadcasting large task binary with size 1346.5 KiB
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1312.9 KiB
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1348.9 KiB
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1313.4 KiB
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1351.9 KiB
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1314.0 KiB
# 25/05/20 23:08:57 WARN BlockManager: Asked to remove block rdd_30806_12, which does not exist
# 25/05/20 23:08:57 WARN DAGScheduler: Broadcasting large task binary with size 1352.7 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1315.0 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1353.2 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1316.7 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1354.0 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1319.5 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1355.1 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1323.3 KiB
# 25/05/20 23:08:58 WARN DAGScheduler: Broadcasting large task binary with size 1357.2 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1324.3 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1360.3 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1324.8 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1365.6 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1325.6 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1367.5 KiB
# 25/05/20 23:08:59 WARN DAGScheduler: Broadcasting large task binary with size 1326.4 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1328.1 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1368.0 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1330.6 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1368.8 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1333.5 KiB
# 25/05/20 23:09:00 WARN DAGScheduler: Broadcasting large task binary with size 1369.6 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1371.1 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1334.0 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1373.0 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1334.5 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1375.7 KiB
# 25/05/20 23:09:01 WARN DAGScheduler: Broadcasting large task binary with size 1335.3 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1336.3 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1376.6 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1338.4 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1377.1 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1341.1 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1377.9 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1344.8 KiB
# 25/05/20 23:09:02 WARN DAGScheduler: Broadcasting large task binary with size 1378.7 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1346.0 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1380.4 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1383.3 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1346.5 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1387.9 KiB
# 25/05/20 23:09:03 WARN DAGScheduler: Broadcasting large task binary with size 1347.3 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1348.4 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1389.8 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1350.2 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1390.3 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1353.1 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1391.1 KiB
# 25/05/20 23:09:04 WARN DAGScheduler: Broadcasting large task binary with size 1357.5 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1392.2 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1358.1 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1394.0 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1397.4 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1358.6 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1402.6 KiB
# 25/05/20 23:09:05 WARN DAGScheduler: Broadcasting large task binary with size 1359.4 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1360.2 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1404.0 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1361.8 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1404.5 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1363.8 KiB
# 25/05/20 23:09:06 WARN DAGScheduler: Broadcasting large task binary with size 1405.3 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1366.3 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1406.4 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1367.1 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1408.5 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1412.2 KiB
# 25/05/20 23:09:07 WARN DAGScheduler: Broadcasting large task binary with size 1367.6 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1368.4 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1417.0 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1369.4 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1418.5 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1371.9 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1419.0 KiB
# 25/05/20 23:09:08 WARN DAGScheduler: Broadcasting large task binary with size 1375.8 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1419.8 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1381.0 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1420.9 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1382.2 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1423.3 KiB
# 25/05/20 23:09:09 WARN DAGScheduler: Broadcasting large task binary with size 1382.7 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1426.8 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1383.5 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1431.5 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1384.6 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1432.5 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1386.7 KiB
# 25/05/20 23:09:10 WARN DAGScheduler: Broadcasting large task binary with size 1433.0 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1390.3 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1433.8 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1396.2 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1434.9 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1397.3 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1436.8 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1397.8 KiB
# 25/05/20 23:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1439.9 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1398.6 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1443.5 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1399.4 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1444.1 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1401.2 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1444.6 KiB
# 25/05/20 23:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1403.7 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1445.3 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1407.0 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1446.4 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1407.5 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1448.9 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1408.0 KiB
# 25/05/20 23:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1452.9 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1408.8 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1458.4 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1409.8 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1458.1 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1412.0 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1458.6 KiB
# 25/05/20 23:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1415.9 KiB
# 25/05/20 23:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1459.2 KiB
# 25/05/20 23:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1421.9 KiB
# 25/05/20 23:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1460.1 KiB
# 25/05/20 23:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1422.1 KiB
# 25/05/20 23:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1461.6 KiB
# ...
# 25/05/20 23:28:33 WARN DAGScheduler: Broadcasting large task binary with size 1203.0 KiB
# 25/05/20 23:28:33 WARN DAGScheduler: Broadcasting large task binary with size 1206.0 KiB
# 25/05/20 23:28:34 WARN DAGScheduler: Broadcasting large task binary with size 1207.1 KiB
# 25/05/20 23:28:34 WARN DAGScheduler: Broadcasting large task binary with size 1207.6 KiB
# 25/05/20 23:28:34 WARN DAGScheduler: Broadcasting large task binary with size 1208.3 KiB
# 25/05/20 23:28:35 WARN DAGScheduler: Broadcasting large task binary with size 1209.4 KiB
# 25/05/20 23:28:35 WARN DAGScheduler: Broadcasting large task binary with size 1211.2 KiB
# 25/05/20 23:28:35 WARN DAGScheduler: Broadcasting large task binary with size 1214.2 KiB
# 25/05/20 23:28:35 WARN DAGScheduler: Broadcasting large task binary with size 1219.3 KiB
# 25/05/20 23:28:36 WARN DAGScheduler: Broadcasting large task binary with size 1221.9 KiB
# 25/05/20 23:28:36 WARN DAGScheduler: Broadcasting large task binary with size 1222.4 KiB
# 25/05/20 23:28:36 WARN DAGScheduler: Broadcasting large task binary with size 1223.2 KiB
# 25/05/20 23:28:37 WARN DAGScheduler: Broadcasting large task binary with size 1224.3 KiB
# 25/05/20 23:28:37 WARN DAGScheduler: Broadcasting large task binary with size 1226.7 KiB
# 25/05/20 23:28:37 WARN DAGScheduler: Broadcasting large task binary with size 1230.4 KiB
# 25/05/20 23:28:38 WARN DAGScheduler: Broadcasting large task binary with size 1235.6 KiB
# 25/05/20 23:28:38 WARN DAGScheduler: Broadcasting large task binary with size 1236.8 KiB
# 25/05/20 23:28:38 WARN DAGScheduler: Broadcasting large task binary with size 1237.3 KiB
# 25/05/20 23:28:39 WARN DAGScheduler: Broadcasting large task binary with size 1238.1 KiB
# 25/05/20 23:28:39 WARN DAGScheduler: Broadcasting large task binary with size 1239.2 KiB
# 25/05/20 23:28:39 WARN DAGScheduler: Broadcasting large task binary with size 1240.6 KiB
# 25/05/20 23:28:39 WARN DAGScheduler: Broadcasting large task binary with size 1242.8 KiB
# 25/05/20 23:28:40 WARN DAGScheduler: Broadcasting large task binary with size 1246.0 KiB
# 25/05/20 23:28:40 WARN DAGScheduler: Broadcasting large task binary with size 1247.4 KiB
# 25/05/20 23:28:40 WARN DAGScheduler: Broadcasting large task binary with size 1247.9 KiB
# 25/05/20 23:28:41 WARN DAGScheduler: Broadcasting large task binary with size 1248.7 KiB
# 25/05/20 23:28:41 WARN DAGScheduler: Broadcasting large task binary with size 1249.7 KiB
# 25/05/20 23:28:41 WARN DAGScheduler: Broadcasting large task binary with size 1251.3 KiB
# 25/05/20 23:28:42 WARN DAGScheduler: Broadcasting large task binary with size 1253.8 KiB
# 25/05/20 23:28:42 WARN DAGScheduler: Broadcasting large task binary with size 1258.7 KiB
# 25/05/20 23:28:42 WARN DAGScheduler: Broadcasting large task binary with size 1260.8 KiB
# 25/05/20 23:28:43 WARN DAGScheduler: Broadcasting large task binary with size 1261.3 KiB
# 25/05/20 23:28:43 WARN DAGScheduler: Broadcasting large task binary with size 1262.1 KiB
# 25/05/20 23:28:43 WARN DAGScheduler: Broadcasting large task binary with size 1262.9 KiB
# 25/05/20 23:28:44 WARN DAGScheduler: Broadcasting large task binary with size 1264.7 KiB
# 25/05/20 23:28:44 WARN DAGScheduler: Broadcasting large task binary with size 1267.7 KiB
# 25/05/20 23:28:44 WARN DAGScheduler: Broadcasting large task binary with size 1271.3 KiB
# 25/05/20 23:28:45 WARN DAGScheduler: Broadcasting large task binary with size 1271.7 KiB
# 25/05/20 23:28:45 WARN DAGScheduler: Broadcasting large task binary with size 1272.2 KiB
# 25/05/20 23:28:45 WARN DAGScheduler: Broadcasting large task binary with size 1273.0 KiB
# 25/05/20 23:28:46 WARN DAGScheduler: Broadcasting large task binary with size 1273.8 KiB
# 25/05/20 23:28:46 WARN DAGScheduler: Broadcasting large task binary with size 1275.7 KiB
# 25/05/20 23:28:46 WARN DAGScheduler: Broadcasting large task binary with size 1279.0 KiB
# 25/05/20 23:28:46 WARN DAGScheduler: Broadcasting large task binary with size 1284.0 KiB
# 25/05/20 23:28:47 WARN DAGScheduler: Broadcasting large task binary with size 1285.5 KiB
# 25/05/20 23:28:47 WARN DAGScheduler: Broadcasting large task binary with size 1286.0 KiB
# 25/05/20 23:28:48 WARN DAGScheduler: Broadcasting large task binary with size 1286.8 KiB
# 25/05/20 23:28:48 WARN DAGScheduler: Broadcasting large task binary with size 1287.9 KiB
# 25/05/20 23:28:48 WARN DAGScheduler: Broadcasting large task binary with size 1289.7 KiB
# 25/05/20 23:28:49 WARN DAGScheduler: Broadcasting large task binary with size 1291.6 KiB
# 25/05/20 23:28:49 WARN DAGScheduler: Broadcasting large task binary with size 1294.1 KiB
# 25/05/20 23:28:49 WARN DAGScheduler: Broadcasting large task binary with size 1295.1 KiB
# 25/05/20 23:28:50 WARN DAGScheduler: Broadcasting large task binary with size 1295.6 KiB
# 25/05/20 23:28:50 WARN DAGScheduler: Broadcasting large task binary with size 1296.4 KiB
# 25/05/20 23:28:50 WARN DAGScheduler: Broadcasting large task binary with size 1297.2 KiB
# 25/05/20 23:28:51 WARN DAGScheduler: Broadcasting large task binary with size 1299.1 KiB
# 25/05/20 23:28:51 WARN DAGScheduler: Broadcasting large task binary with size 1302.2 KiB
# 25/05/20 23:28:51 WARN DAGScheduler: Broadcasting large task binary with size 1307.5 KiB
# 25/05/20 23:28:52 WARN DAGScheduler: Broadcasting large task binary with size 1308.9 KiB
# 25/05/20 23:28:52 WARN DAGScheduler: Broadcasting large task binary with size 1309.4 KiB
# 25/05/20 23:28:52 WARN DAGScheduler: Broadcasting large task binary with size 1310.2 KiB
# 25/05/20 23:28:53 WARN DAGScheduler: Broadcasting large task binary with size 1311.3 KiB
# 25/05/20 23:28:53 WARN DAGScheduler: Broadcasting large task binary with size 1313.8 KiB
# 25/05/20 23:28:53 WARN DAGScheduler: Broadcasting large task binary with size 1318.2 KiB
# 25/05/20 23:28:54 WARN DAGScheduler: Broadcasting large task binary with size 1324.9 KiB
# 25/05/20 23:28:54 WARN DAGScheduler: Broadcasting large task binary with size 1327.2 KiB
# 25/05/20 23:28:54 WARN DAGScheduler: Broadcasting large task binary with size 1327.7 KiB
# 25/05/20 23:28:55 WARN DAGScheduler: Broadcasting large task binary with size 1328.5 KiB
# 25/05/20 23:28:55 WARN DAGScheduler: Broadcasting large task binary with size 1329.3 KiB
# 25/05/20 23:28:55 WARN DAGScheduler: Broadcasting large task binary with size 1330.9 KiB
# 25/05/20 23:28:56 WARN DAGScheduler: Broadcasting large task binary with size 1333.6 KiB
# 25/05/20 23:28:56 WARN DAGScheduler: Broadcasting large task binary with size 1338.0 KiB
# 25/05/20 23:28:56 WARN DAGScheduler: Broadcasting large task binary with size 1339.3 KiB
# 25/05/20 23:28:57 WARN DAGScheduler: Broadcasting large task binary with size 1339.8 KiB
# 25/05/20 23:28:57 WARN DAGScheduler: Broadcasting large task binary with size 1340.4 KiB
# 25/05/20 23:28:57 WARN DAGScheduler: Broadcasting large task binary with size 1341.3 KiB
# 25/05/20 23:28:58 WARN DAGScheduler: Broadcasting large task binary with size 1342.8 KiB
# 25/05/20 23:28:58 WARN DAGScheduler: Broadcasting large task binary with size 1345.5 KiB
# 25/05/20 23:28:58 WARN DAGScheduler: Broadcasting large task binary with size 1348.5 KiB
# 25/05/20 23:28:59 WARN DAGScheduler: Broadcasting large task binary with size 1349.7 KiB
# 25/05/20 23:28:59 WARN DAGScheduler: Broadcasting large task binary with size 1350.2 KiB
# 25/05/20 23:28:59 WARN DAGScheduler: Broadcasting large task binary with size 1351.0 KiB
# 25/05/20 23:29:00 WARN DAGScheduler: Broadcasting large task binary with size 1352.1 KiB
# 25/05/20 23:29:00 WARN DAGScheduler: Broadcasting large task binary with size 1354.2 KiB
# 25/05/20 23:29:01 WARN DAGScheduler: Broadcasting large task binary with size 1357.1 KiB
# 25/05/20 23:29:01 WARN DAGScheduler: Broadcasting large task binary with size 1361.0 KiB
# 25/05/20 23:29:01 WARN DAGScheduler: Broadcasting large task binary with size 1362.6 KiB
# 25/05/20 23:29:02 WARN DAGScheduler: Broadcasting large task binary with size 1363.2 KiB
# 25/05/20 23:29:02 WARN DAGScheduler: Broadcasting large task binary with size 1363.9 KiB
# 25/05/20 23:29:02 WARN DAGScheduler: Broadcasting large task binary with size 1365.0 KiB
# 25/05/20 23:29:03 WARN DAGScheduler: Broadcasting large task binary with size 1366.8 KiB
# 25/05/20 23:29:03 WARN DAGScheduler: Broadcasting large task binary with size 1370.1 KiB
# 25/05/20 23:29:03 WARN DAGScheduler: Broadcasting large task binary with size 1375.2 KiB
# 25/05/20 23:29:04 WARN DAGScheduler: Broadcasting large task binary with size 1376.8 KiB
# 25/05/20 23:29:04 WARN DAGScheduler: Broadcasting large task binary with size 1377.3 KiB
# 25/05/20 23:29:04 WARN DAGScheduler: Broadcasting large task binary with size 1378.1 KiB
# 25/05/20 23:29:05 WARN DAGScheduler: Broadcasting large task binary with size 1379.1 KiB
# 25/05/20 23:29:05 WARN DAGScheduler: Broadcasting large task binary with size 1381.3 KiB
# 25/05/20 23:29:05 WARN DAGScheduler: Broadcasting large task binary with size 1384.4 KiB
# 25/05/20 23:29:06 WARN DAGScheduler: Broadcasting large task binary with size 1388.9 KiB
# 25/05/20 23:29:06 WARN DAGScheduler: Broadcasting large task binary with size 1390.9 KiB
# 25/05/20 23:29:06 WARN DAGScheduler: Broadcasting large task binary with size 1391.4 KiB
# 25/05/20 23:29:07 WARN DAGScheduler: Broadcasting large task binary with size 1392.2 KiB
# 25/05/20 23:29:07 WARN DAGScheduler: Broadcasting large task binary with size 1393.3 KiB
# 25/05/20 23:29:07 WARN DAGScheduler: Broadcasting large task binary with size 1395.1 KiB
# 25/05/20 23:29:07 WARN DAGScheduler: Broadcasting large task binary with size 1397.8 KiB
# 25/05/20 23:29:08 WARN DAGScheduler: Broadcasting large task binary with size 1401.5 KiB
# 25/05/20 23:29:08 WARN DAGScheduler: Broadcasting large task binary with size 1402.0 KiB
# 25/05/20 23:29:09 WARN DAGScheduler: Broadcasting large task binary with size 1402.5 KiB
# 25/05/20 23:29:09 WARN DAGScheduler: Broadcasting large task binary with size 1403.3 KiB
# 25/05/20 23:29:09 WARN DAGScheduler: Broadcasting large task binary with size 1404.4 KiB
# 25/05/20 23:29:09 WARN DAGScheduler: Broadcasting large task binary with size 1406.5 KiB
# 25/05/20 23:29:10 WARN DAGScheduler: Broadcasting large task binary with size 1409.9 KiB
# 25/05/20 23:29:10 WARN DAGScheduler: Broadcasting large task binary with size 1415.4 KiB
# 25/05/20 23:29:10 WARN DAGScheduler: Broadcasting large task binary with size 1416.8 KiB
# 25/05/20 23:29:11 WARN DAGScheduler: Broadcasting large task binary with size 1417.3 KiB
# 25/05/20 23:29:11 WARN DAGScheduler: Broadcasting large task binary with size 1417.9 KiB
# 25/05/20 23:29:11 WARN DAGScheduler: Broadcasting large task binary with size 1418.5 KiB
# 25/05/20 23:29:12 WARN DAGScheduler: Broadcasting large task binary with size 1419.5 KiB
# 25/05/20 23:29:12 WARN DAGScheduler: Broadcasting large task binary with size 1421.1 KiB
# 25/05/20 23:29:12 WARN DAGScheduler: Broadcasting large task binary with size 1423.5 KiB
# 25/05/20 23:29:13 WARN DAGScheduler: Broadcasting large task binary with size 1424.7 KiB
# 25/05/20 23:29:13 WARN DAGScheduler: Broadcasting large task binary with size 1425.3 KiB
# 25/05/20 23:29:13 WARN DAGScheduler: Broadcasting large task binary with size 1426.0 KiB
# 25/05/20 23:29:14 WARN DAGScheduler: Broadcasting large task binary with size 1426.8 KiB
# 25/05/20 23:29:14 WARN DAGScheduler: Broadcasting large task binary with size 1428.4 KiB
# 25/05/20 23:29:14 WARN DAGScheduler: Broadcasting large task binary with size 1430.9 KiB
# 25/05/20 23:29:15 WARN DAGScheduler: Broadcasting large task binary with size 1434.9 KiB
# 25/05/20 23:29:15 WARN DAGScheduler: Broadcasting large task binary with size 1436.5 KiB
# 25/05/20 23:29:15 WARN DAGScheduler: Broadcasting large task binary with size 1437.0 KiB
# 25/05/20 23:29:16 WARN DAGScheduler: Broadcasting large task binary with size 1437.8 KiB
# 25/05/20 23:29:16 WARN DAGScheduler: Broadcasting large task binary with size 1438.8 KiB
# 25/05/20 23:29:16 WARN DAGScheduler: Broadcasting large task binary with size 1441.3 KiB
# 25/05/20 23:29:17 WARN DAGScheduler: Broadcasting large task binary with size 1445.6 KiB
# 25/05/20 23:29:17 WARN DAGScheduler: Broadcasting large task binary with size 1452.8 KiB
# 25/05/20 23:29:17 WARN DAGScheduler: Broadcasting large task binary with size 1455.4 KiB
# 25/05/20 23:29:18 WARN DAGScheduler: Broadcasting large task binary with size 1456.0 KiB
# 25/05/20 23:29:18 WARN DAGScheduler: Broadcasting large task binary with size 1456.7 KiB
# 25/05/20 23:29:18 WARN DAGScheduler: Broadcasting large task binary with size 1457.8 KiB
# 25/05/20 23:29:19 WARN DAGScheduler: Broadcasting large task binary with size 1460.0 KiB
# 25/05/20 23:29:19 WARN DAGScheduler: Broadcasting large task binary with size 1462.9 KiB
# 25/05/20 23:29:19 WARN DAGScheduler: Broadcasting large task binary with size 1466.5 KiB
# 25/05/20 23:29:20 WARN DAGScheduler: Broadcasting large task binary with size 1467.5 KiB
# 25/05/20 23:29:20 WARN DAGScheduler: Broadcasting large task binary with size 1468.0 KiB
# 25/05/20 23:29:20 WARN DAGScheduler: Broadcasting large task binary with size 1468.8 KiB
# 25/05/20 23:29:21 WARN DAGScheduler: Broadcasting large task binary with size 1469.9 KiB
# 25/05/20 23:29:21 WARN DAGScheduler: Broadcasting large task binary with size 1471.5 KiB
# 25/05/20 23:29:21 WARN DAGScheduler: Broadcasting large task binary with size 1474.2 KiB
# 25/05/20 23:29:21 WARN DAGScheduler: Broadcasting large task binary with size 1478.1 KiB
# 25/05/20 23:29:22 WARN DAGScheduler: Broadcasting large task binary with size 1479.0 KiB
# 25/05/20 23:29:22 WARN DAGScheduler: Broadcasting large task binary with size 1479.5 KiB
# 25/05/20 23:29:22 WARN DAGScheduler: Broadcasting large task binary with size 1480.3 KiB
# 25/05/20 23:29:23 WARN DAGScheduler: Broadcasting large task binary with size 1481.4 KiB
# 25/05/20 23:29:23 WARN DAGScheduler: Broadcasting large task binary with size 1483.3 KiB
# 25/05/20 23:29:23 WARN DAGScheduler: Broadcasting large task binary with size 1485.4 KiB
# 25/05/20 23:29:24 WARN DAGScheduler: Broadcasting large task binary with size 1488.4 KiB
# 25/05/20 23:29:24 WARN DAGScheduler: Broadcasting large task binary with size 1488.6 KiB
# 25/05/20 23:29:24 WARN DAGScheduler: Broadcasting large task binary with size 1489.1 KiB
# 25/05/20 23:29:25 WARN DAGScheduler: Broadcasting large task binary with size 1489.9 KiB
# 25/05/20 23:29:25 WARN DAGScheduler: Broadcasting large task binary with size 1491.0 KiB
# 25/05/20 23:29:25 WARN DAGScheduler: Broadcasting large task binary with size 1493.2 KiB
# 25/05/20 23:29:26 WARN DAGScheduler: Broadcasting large task binary with size 1496.8 KiB
# 25/05/20 23:29:26 WARN DAGScheduler: Broadcasting large task binary with size 1501.5 KiB
# 25/05/20 23:29:26 WARN DAGScheduler: Broadcasting large task binary with size 1501.8 KiB
# 25/05/20 23:29:27 WARN DAGScheduler: Broadcasting large task binary with size 1502.3 KiB
# 25/05/20 23:29:27 WARN DAGScheduler: Broadcasting large task binary with size 1503.1 KiB
# 25/05/20 23:29:27 WARN DAGScheduler: Broadcasting large task binary with size 1504.2 KiB
# 25/05/20 23:29:27 WARN DAGScheduler: Broadcasting large task binary with size 1505.7 KiB
# 25/05/20 23:29:28 WARN DAGScheduler: Broadcasting large task binary with size 1507.9 KiB
# 25/05/20 23:29:28 WARN DAGScheduler: Broadcasting large task binary with size 1510.9 KiB
# 25/05/20 23:29:28 WARN DAGScheduler: Broadcasting large task binary with size 1512.2 KiB
# 25/05/20 23:29:29 WARN DAGScheduler: Broadcasting large task binary with size 1512.7 KiB
# 25/05/20 23:29:29 WARN DAGScheduler: Broadcasting large task binary with size 1513.5 KiB
# 25/05/20 23:29:29 WARN DAGScheduler: Broadcasting large task binary with size 1514.5 KiB
# 25/05/20 23:29:30 WARN DAGScheduler: Broadcasting large task binary with size 1516.3 KiB
# 25/05/20 23:29:30 WARN DAGScheduler: Broadcasting large task binary with size 1518.8 KiB
# 25/05/20 23:29:30 WARN DAGScheduler: Broadcasting large task binary with size 1522.1 KiB
# MAE: 1.9779096838889811
# RMSE: 3.1827300997375256
# MSE: 10.129770887775239
# [Stage 28275:==========================================>          (12 + 3) / 15]
# R2: 0.41109047422840483

# %% [markdown]
# ### RESULTS

# %% [markdown]
# GBT Regressor achieves the best performance across all metrics: lowest MAE, RMSE, and MSE, and the highest R² (0.41). This suggests it is not only more accurate in its predictions on average but also better at explaining the variance in the data. As a boosting method, it incrementally corrects errors from previous models, leading to improved accuracy and generalization when properly tuned.

# %% [markdown]
# ## FINAL MODEL COMPARISON

# %% [markdown]
# | Model             | MAE  | RMSE | MSE   | R²   |
# | ----------------- | ---- | ---- | ----- | ---- |
# | Linear Regression | 2.15 | 3.35 | 11.28 | 0.34 |
# | Decision Tree     | 2.02 | 3.22 | 10.36 | 0.39 |
# | Random Forest     | 2.04 | 3.22 | 10.37 | 0.39 |
# | GBT Regressor     | 1.96 | 3.18 | 10.12 | 0.41 |

# %% [markdown]
# The GBT Regressor stands out as the most effective model in this evaluation. It outperforms the others across all key metrics, indicating better average prediction accuracy and stronger ability to capture the underlying patterns in the data.
#
# While Random Forest and Decision Tree offer good performance with similar results, GBT is the best choice when maximum predictive accuracy and variance explanation are desired. However, it may come with higher computational cost and tuning complexity.

# %% [markdown]
# ## References:
#
# https://stackoverflow.com/questions/73524197/pyspark-performing-one-hot-encoding
#
# https://www.datatechnotes.com/2021/05/mllib-linear-regression-example-with.html
#
# https://spark.apache.org/docs/latest/api/python/reference/pyspark.ml.html
#
# https://github.com/RezvanRah/ML_TaxiFare_Prediction
#
# https://www.youtube.com/watch?v=HK4YW9qvQE8
